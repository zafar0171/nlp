# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\modza\documents\nlp\env\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\modza\documents\nlp\env\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\modza\documents\nlp\env\lib\site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\modza\documents\nlp\env\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\modza\documents\nlp\env\lib\site-packages (from nltk>=3.1->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\modza\documents\nlp\env\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\modza\documents\nlp\env\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)

# %%
import spacy
from spacy.matcher import Matcher
from textblob import TextBlob

# Load the transformer-based model
nlp = spacy.load("en_core_web_trf")

# Define the headlines
headlines = [
    "Tomato rates soar as Centre looks to south for new stock",
    "Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate"
]

# Define categories and keywords with synonyms
positive_keywords = ["approves", "investment", "expansion", "success", "high", "best ever", "fly high", "jump", "rallied", "surge", "increase", "rise", "gain", "soar", "profit"]
negative_keywords = ["loser", "fall", "decline", "drop", "decrease", "plunge", "slump", "crash", "fraud"]
sectorial_keywords = ["energy stocks", "aviation", "renewable energy"]
recommendation_keywords = ["planning to buy", "brokerages views", "recommendations"]
deal_keywords = ["raising", "investment target", "IPO", "stake", "valuation"]

# Initialize the matcher
matcher = Matcher(nlp.vocab)

# Define patterns for specific phrases including entities
patterns = [
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "of"}, {"ENT_TYPE": "ORG"}, {"LOWER": "top"}, {"LOWER": "picks"}],
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "suggested"}, {"LOWER": "this"}],
    [{"LOWER": "breakout"}, {"LOWER": "stock"}],
    [{"LOWER": "price"}, {"LOWER": "volume"}, {"LOWER": "breakouts"}],
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "recommends"}, {"LOWER": "this"}]
]

# Add patterns to matcher
for pattern in patterns:
    matcher.add("TOP_PICK_PATTERNS", [pattern])

# Function to classify headline
def classify_headline(headline):
    doc = nlp(headline)
    matches = matcher(doc)
    
    if matches:
        return "Top Picks"
    
    category = None
    sentiment = TextBlob(headline).sentiment.polarity

    # Dependency parsing and context check
    for token in doc:
        if token.lemma_ in positive_keywords and any([ent.label_ == "ORG" for ent in doc.ents]):
            return "Positive News"
        elif token.lemma_ in negative_keywords and any([ent.label_ == "ORG" for ent in doc.ents]):
            return "Negative News"
        elif token.lemma_ in sectorial_keywords:
            return "Sectorial News"
        elif token.lemma_ in recommendation_keywords:
            return "Stock Recommendations"
        elif token.lemma_ in deal_keywords:
            return "Deals"
    
    # Use sentiment analysis to determine positive or negative context
    if sentiment > 0:
        return "Positive News"
    elif sentiment < 0:
        return "Negative News"
    
    return category

# Process headlines and classify
alerts = []
for headline in headlines:
    category = classify_headline(headline)
    if category:
        alerts.append((headline, category))

# Print alerts
for alert in alerts:
    print(f"Category: {alert[1]}\nHeadline: {alert[0]}\n")
# Out:
# Category: Positive News
# Headline: Tomato rates soar as Centre looks to south for new stock

# %%
import spacy
from spacy.matcher import Matcher
from textblob import TextBlob
from transformers import pipeline
import torch

# Load the transformer-based model for spaCy
nlp = spacy.load("en_core_web_trf")

# Load the sentiment analysis pipeline from transformers
sentiment_pipeline = pipeline("sentiment-analysis")

# Define the headlines
headlines = [
    "Tomato rates soar as Centre looks to south for new stock",
    "Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate"
]

# Define categories and keywords with synonyms
positive_keywords = ["approves", "investment", "expansion", "success", "high", "best ever", "fly high", "jump", "rallied", "surge", "increase", "rise", "gain", "soar", "profit"]
negative_keywords = ["loser", "fall", "decline", "drop", "decrease", "plunge", "slump", "crash", "fraud"]
sectorial_keywords = ["energy stocks", "aviation", "renewable energy"]
recommendation_keywords = ["planning to buy", "brokerages views", "recommendations"]
deal_keywords = ["raising", "investment target", "IPO", "stake", "valuation"]

# Initialize the matcher
matcher = Matcher(nlp.vocab)

# Define patterns for specific phrases including entities
patterns = [
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "of"}, {"ENT_TYPE": "ORG"}, {"LOWER": "top"}, {"LOWER": "picks"}],
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "suggested"}, {"LOWER": "this"}],
    [{"LOWER": "breakout"}, {"LOWER": "stock"}],
    [{"LOWER": "price"}, {"LOWER": "volume"}, {"LOWER": "breakouts"}],
    [{"ENT_TYPE": "PERSON"}, {"LOWER": "recommends"}, {"LOWER": "this"}]
]

# Add patterns to matcher
for pattern in patterns:
    matcher.add("TOP_PICK_PATTERNS", [pattern])

# Function to perform sentiment analysis using transformers
def transformer_sentiment_analysis(headline):
    result = sentiment_pipeline(headline)[0]
    label = result['label']
    score = result['score']
    return label, score

# Function to classify headline
def classify_headline(headline):
    doc = nlp(headline)
    matches = matcher(doc)

    if matches:
        return "Top Picks"
    
    category = None
    # Sentiment analysis
    label, score = transformer_sentiment_analysis(headline)
    
    if label == "POSITIVE":
        for token in doc:
            if token.lemma_ in positive_keywords and any([ent.label_ == "ORG" for ent in doc.ents]):
                return "Positive News"
    elif label == "NEGATIVE":
        for token in doc:
            if token.lemma_ in negative_keywords and any([ent.label_ == "ORG" for ent in doc.ents]):
                return "Negative News"

    # Check for sectorial, recommendation, and deal keywords
    for token in doc:
        if token.lemma_ in sectorial_keywords:
            return "Sectorial News"
        elif token.lemma_ in recommendation_keywords:
            return "Stock Recommendations"
        elif token.lemma_ in deal_keywords:
            return "Deals"
    
    # Default to sentiment analysis result if no specific category matches
    if label == "POSITIVE":
        return "Positive News"
    elif label == "NEGATIVE":
        return "Negative News"
    
    return category

# Process headlines and classify
alerts = []
for headline in headlines:
    category = classify_headline(headline)
    if category:
        alerts.append((headline, category))

# Print alerts
for alert in alerts:
    print(f"Category: {alert[1]}\nHeadline: {alert[0]}\n")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# C:\Users\modza\Documents\nlp\env\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\Users\modza\Documents\nlp\env\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\modza\.cache\huggingface\hub\models--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Category: Negative News
# Headline: Tomato rates soar as Centre looks to south for new stock
#
# Category: Positive News
# Headline: Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate

# %%
import pandas as pd
df = pd.read_csv("Data_for_semantic_analysis.csv",index_col = 0)
df.head()
# Out:
#                                             headline          news_category  \
# 0  'Will explore legal options': Kotak Bank probi...  Company Business News
# 1  ONGC Leads Nifty Gainers With 3% Gain As Marke...                    NaN
# 2  SBI wants tax parity on bank FDs with mutual f...                    NaN
# 3  Rs 85,000 Crore Order Book: Railway Infra Comp...                    NaN
# 4  Trade Setup For July 9: Investors Await Q1 Ear...                    NaN
#
#                                 org
# 0                              Mint
# 1                    Benzinga India
# 2                The Economic Times
# 3   Dalal Street Investment Journal
# 4                       NDTV Profit

# %%
alerts = []
for headline in df.headline:
    category = classify_headline(headline)
    if category:
        alerts.append((headline, category))

# Print alerts
for alert in alerts:
    print(f"Category: {alert[1]}\nHeadline: {alert[0]}\n")
# Out:
# Category: Positive News
# Headline: 'Will explore legal options': Kotak Bank probing if Kingdon Capital hid Hindenburg Research links
#
# Category: Negative News
# Headline: ONGC Leads Nifty Gainers With 3% Gain As Market Ends Flat On Monday
#
# Category: Negative News
# Headline: SBI wants tax parity on bank FDs with mutual funds & equity markets in Budget
#
# Category: Negative News
# Headline: Rs 85,000 Crore Order Book: Railway Infra Company Hits Fresh 52-Week High with Heavy Volumes; Stock Gains 370 per cent in Just 1 Year
#
# Category: Negative News
# Headline: Trade Setup For July 9: Investors Await Q1 Earnings As Nifty Faces Key Resistance Levels
#
# Category: Negative News
# Headline: Ola replaces Google Maps with in-house ‘Ola Maps’, announces API for developers
#
# Category: Negative News
# Headline: Tata Motors Q1 update: Global wholesales increase 2% YoY; stock jumps
#
# Category: Positive News
# Headline: Kia India Introduces New Variants For Seltos, Sonet
#
# Category: Negative News
# Headline: Liver Doc slams Nikhil Kamath for glorifying 'business of alcohol' in his podcast: 'It's a crime'
#
# Category: Positive News
# Headline: L&T Enhances its Renewables Portfolio: Finalises (Mega*) Orders for Solar Plants in the Middle East
#
# Category: Negative News
# Headline: Adani Wilmar shares jump over 4% despite weak stock market trends. More steam left?
#
# Category: Deals
# Headline: Blackstone in advanced talks for controlling stake in Haldiram's
#
# Category: Deals
# Headline: Emcure Pharma IPO allotment status: Check step-by-step guide
#
# Category: Negative News
# Headline: Titan gets a downgrade as Street turns cautious post Q1 business update
#
# Category: Positive News
# Headline: Bajaj Freedom 125: Top 10 Stats About The World’s First CNG Motorcycle
#
# Category: Negative News
# Headline: Zinka Logistics Headed For ₹550 Cr IPO, Files Prospectus
#
# Category: Negative News
# Headline: Brightcom Group, Bohra Industries & others hit 52 week low today ;Check the full list here?
#
# Category: Negative News
# Headline: 3 new Jio 5G True Unlimited Upgrade plans available now: how to get them
#
# Category: Positive News
# Headline: Retail investors key force behind market's stellar performance: Report
#
# Category: Positive News
# Headline: Nifty In Technical Charts: Stay The Course But Be Alert
#
# Category: Positive News
# Headline: Ashish Kacholia Backed Small Cap Stock Hits All-Time High After Bagging ₹1850 Cr Order
#
# Category: Negative News
# Headline: Apple may revive plans to make iPads in India, eyes Pune for AirPod cases
#
# Category: Deals
# Headline: Paytm stock zooms 9% after Vijay Shekhar Sharma aims for $100 billion valuation
#
# Category: Negative News
# Headline: Top Gainers and Losers today on 8 July, 2024: Oil & Natural Gas Corporation, ITC, Divis Laboratories, Titan Company among most active stocks; Check full list here
#
# Category: Negative News
# Headline: SJVN share price target 2024: Rs 1 lakh became Rs 3 lakh in 1 yr! Time to BUY PSU stock for more gains?
#
# Category: Negative News
# Headline: NHPC Shares Extend Gains To 4th Day As Brokerage Issues 'Buy' Call
#
# Category: Negative News
# Headline: Toyota Dealer In UP Offers 100% Road Tax Waiver On Hybrids - Innova HyCross, HyRyder, Camry (Up To Rs 4.4 ...
#
# Category: Negative News
# Headline: Bansal Wire IPO allotment to be finalised today: latest GMP, step-by-step guide to check status
#
# Category: Negative News
# Headline: Housing prices in NCR and MMR surge 49% in 5 years, unsold inventory plunges: ANAROCK
#
# Category: Positive News
# Headline: Gold price in India: Rates on July 8
#
# Category: Negative News
# Headline: Maruti Suzuki Dispatch Via Indian Railways Cross Record 20 Lakh Vehicles
#
# Category: Positive News
# Headline: Heatwave And Monsoon Spur Infection Surge; Augmentin, Liv 52, Electral Sales Rise in June
#
# Category: Negative News
# Headline: PC Jewellers gets PNB clearance for one-time settlement of outstanding dues
#
# Category: Positive News
# Headline: Signature Global reports strong Q1 FY25 performance amid real estate sector challenges
#
# Category: Negative News
# Headline: Patel Engineering share price tanks over 11% after Chairman & MD Rupen Patel passes away
#
# Category: Negative News
# Headline: IRFC shares surge over 9% to a record high; Can the stock reach ₹250?
#
# Category: Positive News
# Headline: Top 10 SUVs June 2024 - Punch, Creta, Brezza, Scorpio, Venue, Sonet, G Vitara
#
# Category: Positive News
# Headline: Tata Curvv EV Teased Ahead of Official Launch, Check Details
#
# Category: Positive News
# Headline: Stocks in news: Nykaa, Adani Wilmar, Titan, Bandhan Bank, IndusInd Bank, Marico, Dabur
#
# Category: Negative News
# Headline: ‘Techno-colonialism’: Bhavish Aggarwal likens tech giants to East India Company, says 20% of global data from India…
#
# Category: Negative News
# Headline: ‘Ather has sh*t marketing, but…’: Nikhil Kamath reveals he didn't get discount on EV scooter
#
# Category: Negative News
# Headline: New private investment plans slumped to 20-year low in Q1
#
# Category: Negative News
# Headline: Nestle India announces first interim dividend for FY25: Check amount, dividend payment date etc.
#
# Category: Positive News
# Headline: Industry experts predict favourable outlook for auto industry, two-wheelers expected to lead
#
# Category: Negative News
# Headline: Bitcoin price today: slips to $57k as Mt Gox jitters rattle crypto By Investing.com
#
# Category: Positive News
# Headline: Option strategy of the day
#
# Category: Positive News
# Headline: IT Q1 FY25 earnings: Five factors to watch out for
#
# Category: Positive News
# Headline: Ratan Tata's company earns Rs 38000 crore in 5 days, becomes biggest...
#
# Category: Positive News
# Headline: Nykaa Share Price Overcomes Early Jitters To Trade Higher On Strong Q1 Update
#
# Category: Negative News
# Headline: Over 6,500 Samsung workers walk off assembly lines over pay, vacation time
#
# Category: Negative News
# Headline: Gold declines as Trump effect pushes up yields
#
# Category: Negative News
# Headline: Stocks to buy: ONGC, TVS Motor, IRFC among 10 stocks that may rise 6-21% in the next 3-4 weeks, say analysts
#
# Category: Negative News
# Headline: AU Small Finance Bank shares tumble over 4% as total deposits decline QoQ
#
# Category: Negative News
# Headline: Adani Green plans $9 billion infrastructure spend on green hydrogen in Phase one: Report
#
# Category: Negative News
# Headline: Stocks to buy or sell: Shilpa Medicare to Shalby — Sumeet Bagadia recommends five breakout stocks
#
# Category: Negative News
# Headline: Tomato rates soar as Centre looks to south for new stock
#
# Category: Negative News
# Headline: Buy Or Exit — Paytm shares up 14% in two sessions, what should you do?
#
# Category: Negative News
# Headline: Bank of Baroda shares in focus after Q1 business update; what should investors do?
#
# Category: Positive News
# Headline: ONDC logs 9.95 million transactions in June, retail category hits 6 million
#
# Category: Negative News
# Headline: Delhi HC releases Rs 80 crore security by Ashneer Grover, Madhuri Jain after they return to India from US
#
# Category: Negative News
# Headline: Tata Steel Shares Remain Flat After Production And Delivery Update
#
# Category: Negative News
# Headline: YES bank shares: Market trading guide: YES Bank, Inox Wind among 5 stock recommendations for Monday - Stock Ideas
#
# Category: Negative News
# Headline: 8 diet and fitness tips to borrow from Nita Ambani
#
# Category: Positive News
# Headline: Air India’s first Airbus aircraft with new livery lands in Delhi
#
# Category: Negative News
# Headline: Stock market today: Bandhan Bank, GNFC, Piramal Enterprises among 6 stocks in F&O ban list on July 8
#
# Category: Negative News
# Headline: IREDA shares rise 8% to hit a record high; An analyst sees upside to levels of ₹270
#
# Category: Negative News
# Headline: Have Mazagon Dock, Cochin Shipyard, Garden Reach shares run up too much, too soon?
#
# Category: Negative News
# Headline: Deposit grows slower than loan for many banks in June quarter of FY25
#
# Category: Negative News
# Headline: Maruti Nexa July 2024 Offers Part 1-Get Discounts Of Up To Rs 2.5 Lakh
#
# Category: Negative News
# Headline: Healthcare focused fintech startup Care.fi raises $2.6 Mn
#
# Category: Deals
# Headline: Reports of 51% stake sale "factually incorrect", says Yes Bank; shares climb
#
# Category: Positive News
# Headline: Maruti shares get a boost after UP waives registration fees on hybrid cars
#
# Category: Positive News
# Headline: Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate
#
# Category: Negative News
# Headline: Natural Gas and Oil Forecast: WTI Slips Below $83; More Sell-Off Ahead?
#
# Category: Negative News
# Headline: RVNL shares see ₹827 crore block deal, second in two days; Stock crosses ₹600
#
# Category: Negative News
# Headline: MCX technical glitch: Commodity trading begins at 10 AM after one hour delay
#
# Category: Negative News
# Headline: Zerodha's Nikhil Kamath says he has invested ₹400 crore in this liquor company: ‘Never spoken about it publicly’
#
# Category: Negative News
# Headline: Stocks in news: Jupiter Wagons, Nestle, RailTel, Bandhan Bank, Godrej Consumer, PG Electropast
#
# Category: Negative News
# Headline: Tata Motors' Global Wholesale Volumes Rise 2% In Q1, Passenger Vehicles Segment Sees Dip
#
# Category: Positive News
# Headline: Kia introduces 5 new trims in Seltos and Sonet, details inside
#
# Category: Positive News
# Headline: Bajaj Auto's CNG bike a bold move; customer adoption a concern: Analysts
#
# Category: Negative News
# Headline: Emcure Pharma IPO allotment – How to check allotment, IPO GMP, listing date and more
#
# Category: Negative News
# Headline: Kotak Mahindra Bank Ponders Whether Kingdon Capital Misrepresented Connection With Hindenburg
#
# Category: Negative News
# Headline: Titan stock slumps 4% after JPMorgan downgrade following weak Q1 biz update
#
# Category: Positive News
# Headline: Q1 Results This Week: TCS, HCLTech, Avenue Supermarts, IREDA, Delta Corp and Tata Elxsi
#
# Category: Negative News
# Headline: Paytm shares jump 9% after Vijay Shekhar Sharma says goal is to build $100 billion company
#
# Category: Negative News
# Headline: MC Exclusive: F&O crackdown: Only one weekly options contract per exchange, min lot size Rs 20-30...
#
# Category: Positive News
# Headline: India added 4.7 crore jobs in FY24; 6% growth double of previous year: RBI data
#
# Category: Negative News
# Headline: GE Power India bags order from NTPC
#
# Category: Negative News
# Headline: Gainers & Losers: Stocks that moved the most on July 8
#
# Category: Negative News
# Headline: After Google Maps Exit, Ola Offers INR 100 Crore Free Credit for Ola Maps
#
# Category: Negative News
# Headline: Wheel falls off United Airlines Boeing moments after takeoff from LA airport: Watch
#
# Category: Positive News
# Headline: Jefferies surprised by Indian market's resilience post election; says midcaps face greatest correction risk
#
# Category: Negative News
# Headline: IT earnings preview: Is it the end of the downgrade cycle?
#
# Category: Positive News
# Headline: With Elon Musk’s Tesla yet to plug into India, government plans changes in new EV policy; tweaks may bene
#
# Category: Positive News
# Headline: Adani to spend $9bn on green hydrogen in Gujarat, with eye on exports: report
#
# Category: Negative News
# Headline: SJVN share price target 2024: Rs 1 lakh became Rs 3 lakh in 1 yr! Time to BUY PSU stock for more gains?
#
# Category: Negative News
# Headline: Bears flock to HDFC Bank counter as loan, deposit growth slows
#
# Category: Negative News
# Headline: Patel Engg chairman Rupen Patel dies at 57
#
# Category: Negative News
# Headline: Raymond share price jumps 18% in 3 days on demerger plans; Should you buy the multibagger stock?
#
# Category: Negative News
# Headline: Tata Curvv Electric Coupe SUV Teased Ahead Of Launch: All You Need To Know
#
# Category: Positive News
# Headline: Koo Founder Announces New Consumer Tech Venture, Seeks Engineering Talent
#
# Category: Positive News
# Headline: Paramount and Skydance merge, signaling end of a family reign in Hollywood and the rise of new power
#
# Category: Negative News
# Headline: Gold price plummets as US yields drop and China stops bullion buying
#
# Category: Negative News
# Headline: More passengers are impacted by delayed flights than ever before, shows data
#
# Category: Positive News
# Headline: Stocks to buy or sell: RVNL, RCF to Alembic — Sumeet Bagadia recommends five breakout stocks today
#
# Category: Positive News
# Headline: Air India welcomes first narrow body aircraft in Delhi
#
# Category: Negative News
# Headline: Indian game firms want to distance themselves from fantasy sports
#
# Category: Positive News
# Headline: Premiumization of Mahindra SUVs holds a mirror to luxury housing: Amit Kumar Sinha, MD, Mahindra Lifespaces
#
# Category: Negative News
# Headline: This Hyundai SUV is Cheaper By Rs 2 Lakh
#
# Category: Deals
# Headline: Blackstone In Talks To Gobble Up Majority Stake In Haldiram's In ₹70000 Cr Deal: Report
#
# Category: Negative News
# Headline: Analyst Call Tracker: Tata Motors emerges as top bet in auto sector, rival Maruti Suzuki sees downgrades
#
# Category: Positive News
# Headline: MC Inside Edge: Sudden and swift jump in fertiliser stocks, three stocks in the limelight in F&O, a risky trend in small caps
#
# Category: Negative News
# Headline: Gautam Adani Plans To Build Ships At Flagship Mundra Port: Report
#
# Category: Negative News
# Headline: Stock market today: BSE Sensex back above 80,100; Nifty50 near 24,350
#
# Category: Positive News
# Headline: RVNL Now Valued Higher Than IRCON, RITES, Jupiter Wagons And Titagarh Combined
#
# Category: Deals
# Headline: SBI Keen To Sell 24% Stake In Yes Bank
#
# Category: Positive News
# Headline: Indian IT eyes modest growth April-June qtr
#
# Category: Negative News
# Headline: Affle India Shares Up 4%, Hit 52-Week High As Citi Initiates Coverage With 'Buy'
#
# Category: Negative News
# Headline: Suzlon Peer Inox Wind Bags Order For Its Wind Turbine Generators, Shares Fly 6%
#
# Category: Negative News
# Headline: How India's Uday Kotak Got Caught in Adani Inquiry in Latest Hindenburg Twist
#
# Category: Positive News
# Headline: L&T expands semiconductor business through ₹183 crore SiliConch acquisition
#
# Category: Negative News
# Headline: Nifty Bank closes lower; strong support placed at 52,000: Experts
#
# Category: Positive News
# Headline: MGL, Pitti Engineering, CONCOR, Senco Gold, Godrej Consumer and more: Stocks to watch on July 9
#
# Category: Negative News
# Headline: Govt. reopens PLI scheme for white goods till October 12
#
# Category: Positive News
# Headline: India added 2.5 times more jobs in FY24, highest since 1981-82: RBI data
#
# Category: Negative News
# Headline: Tea prices soar as heatwaves, floods slash output in key producing regions
#
# Category: Negative News
# Headline: MCX technical glitch: Commodity trading begins at 10 AM after one hour delay
#
# Category: Negative News
# Headline: After iPhone Success, Apple Wants To Revive Its 'Make In India' Plans For iPads And AirPod Cases: Report
#
# Category: Negative News
# Headline: BlackRock buys 4.55 mn shares of Swan Energy worth Rs 304 cr via block deal
#
# Category: Positive News
# Headline: Stocks to buy or sell: RVNL, RCF to Alembic — Sumeet Bagadia recommends five breakout stocks today
#
# Category: Negative News
# Headline: Nuvama Initiates Coverage On This Railway Stock, Sees 21% Upside
#
# Category: Negative News
# Headline: Oil prices plunge on Gaza peace talks, Hurricane Beryl impact; brent crude at $86.12/bbl
#
# Category: Negative News
# Headline: Zerodha glitch: Man explains how he lost Rs 10 lakh, seeks help
#
# Category: Positive News
# Headline: Arnold Schwarzenegger inspired Mercedes with electric car
#
# Category: Positive News
# Headline: Gold jumps ahead of Fed Powell’s testimony
#
# Category: Deals
# Headline: Exclusive: Dezerv Raises $32 Mn From Premji Invest, Others At A Valuation Of Over $200 Mn
#
# Category: Negative News
# Headline: Ducati Hypermotard 698 Mono Launch Price Rs 16.5 Lakh - RVE Arrival Later
#
# Category: Positive News
# Headline: Wall Street today: US stocks edge higher ahead of key economic events, chip shares rally
#
# Category: Positive News
# Headline: Skoda To Launch Premium SUV Kodiaq In India
#
# Category: Negative News
# Headline: PC Jeweller stock hits 10% upper circuit after PNB approves one-time settlement of dues
#
# Category: Positive News
# Headline: Ratan Tata's company earns Rs 38000 crore in 5 days, becomes biggest...
#
# Category: Negative News
# Headline: Trade setup for today: Top 15 things to know before the opening bell
#
# Category: Positive News
# Headline: Equity fund inflows rise by 17% to Rs 40,608 crore in June, a fresh high: AMFI data
#
# Category: Negative News
# Headline: Maruti Suzuki shares surge over 6% as UP govt waives registration fee for hybrid cars; check details
#
# Category: Positive News
# Headline: MC Inside Edge: Sudden and swift jump in fertiliser stocks, three stocks in the limelight in F&O, a...
#
# Category: Positive News
# Headline: MC Exclusive
#
# Category: Deals
# Headline: Amid valuation concerns, HDFC Defence Fund stops new SIP registrations effective July 22
#
# Category: Positive News
# Headline: Inox Wind shares gain nearly 7% after securing 200MW order
#
# Category: Deals
# Headline: Yes Bank stake sale report is factually incorrect, got no approval from RBI: Bank clarifies
#
# Category: Positive News
# Headline: Stocks to watch, July 9: Dixon Tech, Swan Energy, Bajaj Finserv, Senco Gold
#
# Category: Positive News
# Headline: Employment rate rises 6% provisionally in FY24 from 3.2% in FY23: RBI data
#
# Category: Positive News
# Headline: Emcure Pharma IPO: Namita Thapar-backed issue may debut with 30% gains amid high investor interest
#
# Category: Negative News
# Headline: IRFC Share Price Target 2024: Railway stock tumbles after scaling fresh high - Buy, Sell or Hold?
#
# Category: Negative News
# Headline: Hyundai under pressure from Tata, Mahindra as $3.5 billion India IPO looms
#
# Category: Negative News
# Headline: L&T Bags Order For Construction Of 2 Fleet Support Ships For Indian Navy
#
# Category: Negative News
# Headline: Crude oil prices: Brent, WTI shed 0.25% after subdued impact of Hurricane Beryl
#
# Category: Negative News
# Headline: 2024 Mercedes EQA, EQB Electric SUVs India Launch Price From Rs 66 Lakh
#
# Category: Negative News
# Headline: Adani to build ships at Mundra port in Gujarat, will likely focus on green vessels for long-term, says report
#
# Category: Positive News
# Headline: L&T to acquire semiconductor design firm SiliConch
#
# Category: Deals
# Headline: Bansal Wire Industries IPO Allotment Today: A Step-by-Step Guide to Check Status, Check GMP Today
#
# Category: Negative News
# Headline: Apple may start iPad production in India, AirPod charging cases at Jabil facility in Pune, says report
#
# Category: Negative News
# Headline: Indian PhD scholar says Air India forgot to load her suitcase on US flight to Bengaluru: ‘It’s been 36 hours'
#
# Category: Negative News
# Headline: Jupiter Wagons shares plunge 3% despite QIP launch- Find out why?
#
# Category: Negative News
# Headline: Wealthtech startup Dezerv raises $32 Mn in Series B
#
# Category: Positive News
# Headline: Tata Group airlines move a step closer to merger
#
# Category: Negative News
# Headline: Paytm Like A Daughter Who Met With Accident, Now In ICU: Vijay Shekhar Sharma
#
# Category: Deals
# Headline: Swiggy's Early Investors Dilute Stakes Ahead Of Expected IPO: Report
#
# Category: Negative News
# Headline: Unsold Cars Worth Rs 60,000 Crores Lying At Dealers - All Time High Inventory
#
# Category: Positive News
# Headline: Nifty 50 likely to rise in the short term; BHEL, CDSL among top technical picks by Rupak De of LKP Securities
#
# Category: Negative News
# Headline: Trade Spotlight: How should you trade SJVN, Apollo Hospitals, Ircon, Coforge, MIDHANI, and others on...
#
# Category: Positive News
# Headline: HFT Scan: Gujarat Mineral Development Corporation and Ircon International in focus
#
# Category: Negative News
# Headline: Rs 85 IPO GMP Today: 97% latest grey market premium - Check company name
#
# Category: Negative News
# Headline: Quant Mutual Fund investors withdraw Rs 2,800 crore amid Sebi probe: Report
#
# Category: Positive News
# Headline: Accenture Acquires Excelmax Technologies to Expand Silicon Design and Engineering Capabilities - Newsroom
#
# Category: Negative News
# Headline: Ducati Hypermotard 698 Mono Launch Price Rs 16.5 Lakh - RVE Arrival Later
#
# Category: Negative News
# Headline: Wheel falls off United Airlines Boeing moments after takeoff from LA airport: Watch
#
# Category: Positive News
# Headline: Share Market Highlights 9 July 2024: Sensex and Nifty trade firm; Maruti Suzuki surges over 6%
#
# Category: Negative News
# Headline: Wipro settles non-compete lawsuits against former execs, Cognizant pays $505k for settlement
#
# Category: Negative News
# Headline: Crisis-hit Paytm gets govt panel's nod to invest in payments arm: Report
#
# Category: Positive News
# Headline: Freedom Vs Splendor: Bajaj Autos New CNG Foray Gets Thumbs Up From Analysts
#
# Category: Negative News
# Headline: SEBI committee proposes stricter measures to curb derivatives volume; raises lot size to ₹20-30 lakh: Report
#
# Category: Negative News
# Headline: Tata Motors reduces price of Harrier, Safari to provide benefits up to 1,40,000
#
# Category: Positive News
# Headline: New Thematic, Multi-Cap Mutual Funds Drive Equity Inflows To Another Record
#
# Category: Positive News
# Headline: Xiaomi SU7 Electric Car Showcased In India - 10th Anniversary Celebration
#
# Category: Deals
# Headline: SBI To Sell Entire 24% Stake In Yes Bank 4 Years After Rescue: Report
#
# Category: Positive News
# Headline: Good news! Maruti Suzuki cars to now offer more than double warranty on kilometres run: Details
#
# Category: Positive News
# Headline: Mobile tariff hike: These are the most affordable monthly and yearly plans from Reliance Jio and Airtel o
#
# Category: Negative News
# Headline: Adani to build ships at Mundra port in Gujarat, will likely focus on green vessels for long-term, says report
#
# Category: Negative News
# Headline: Mahindra XUV700 AX7 Price Cut By Up To Rs 2.2 Lakh - Official Price List
#
# Category: Positive News
# Headline: Nikhil Kamath's ‘sh*t marketing’ jibe at Ather Energy gets a witty comeback from Bengaluru CEO
#
# Category: Negative News
# Headline: Mumbai and Delhi housing prices soar by 48% in five years as unsold inventory declines
#
# Category: Negative News
# Headline: Zerodha glitch: Man explains how he lost Rs 10 lakh, seeks help
#
# Category: Negative News
# Headline: Microsoft ditches Android for Apple iPhones in China, citing security and authentication issues
#
# Category: Negative News
# Headline: Tata Motors Group global wholesales at 3,29,847 in Q1 FY25
#
# Category: Positive News
# Headline: Mahanagar Gas increases CNG and domestic PNG prices in Mumbai, Report: Check latest rates IGL and Gujarat Gas
#
# Category: Negative News
# Headline: Q1 Results: TCS, DMart, HCL Tech, IREDA Among Companies Declaring Quarterly Earnings This Week
#
# Category: Negative News
# Headline: Netizens Poke Holes In Ola Founder's 'India-Specfic' Narrative As In-House Map Tool Bears Strong Resemblance To OpenStreetMaps
#
# Category: Negative News
# Headline: Bansal Wire IPO: Allotment status out. What GMP signals ahead of share listing date?
#
# Category: Positive News
# Headline: Motilal Oswal Takes Bullish View On ONGC, GAIL Ahead Of Earnings
#
# Category: Positive News
# Headline: Top Power Stock Picks: Investec highlights NHPC, Inox Wind among preference
#
# Category: Positive News
# Headline: Blackrock Buys Shares Worth Rs 304 Crore Of Swan Energy
#
# Category: Negative News
# Headline: Stock to buy: Anand Rathi sees 20% upside for multibagger PSU Hindustan Copper shares, recommends ‘Buy’
#
# Category: Positive News
# Headline: First Tata Curvv EV Official Teasers Out Ahead Of Launch
#
# Category: Positive News
# Headline: Sebi tweaks norms for mutual fund investments in listed securities of sponsor
#
# Category: Negative News
# Headline: Cognizant pays $505,087 to settle non-complete Wipro lawsuit against CFO Jatin Dalal
#
# Category: Negative News
# Headline: HDFC Mutual Fund to discontinue lumpsum subscription and restrict systematic transactions in defence fund
#
# Category: Negative News
# Headline: Maruti Suzuki's Share Price Shoots Up As UP Govt Scraps Tax That Could Save Its Hybrid Buyers Up To ₹3 Lakh
#
# Category: Negative News
# Headline: F&O Trading: Sebi Panel Suggests Rs 20-30 Lakh Minimum Lot Size, One Weekly Options Contract Per Exchange
#
# Category: Negative News
# Headline: TCS Q1FY25 results: PAT may grow 8% YoY to Rs 11,984 crore, revenue uptick seen at 4.8%
#
# Category: Negative News
# Headline: BlackRock buys 4.55 mn shares of Swan Energy worth Rs 304 cr via block deal
#
# Category: Negative News
# Headline: Inflation impact: sambar is luxury, chutney staple in many lower-income households in Bengaluru
#
# Category: Positive News
# Headline: Emcure Pharmaceuticals share price makes a strong debut, stock opens with 31.5% premium at ₹1,325.05 apiece on NSE
#
# Category: Negative News
# Headline: M&M, bank stocks halt D-Street's record run! Sensex sheds 150 points, Nifty below 24,400
#
# Category: Positive News
# Headline: Zomato’s ad for its '16th janamdin' gets a shout-out from Paytm CEO Vijay Shekhar Sharma
#
# Category: Positive News
# Headline: Amazon Pay sees big opportunities in India's small towns, offline payments
#
# Category: Negative News
# Headline: RVNL Bags ₹202.87 Cr Order From South Eastern Railways
#
# Category: Negative News
# Headline: Bullish calls on Maruti after UP's hybrid tax break sends stock higher
#
# Category: Positive News
# Headline: Bansal Wire Industries IPO listing date today. Latest GMP, experts see share listing price at strong premium
#
# Category: Positive News
# Headline: Markets News, July 9, 2024: S&P 500, Nasdaq Inch Higher to Extend Winning Streaks
#
# Category: Negative News
# Headline: Delta Corp share price slumps over 4% on weak Q1 results; net profit dives 68% YoY
#
# Category: Negative News
# Headline: Mutual fund SIPs hit new high of Rs 21,260 crore in June, cross Rs 1 lakh crore mark in 2024
#
# Category: Negative News
# Headline: Buy or sell: Apollo Tyres to Union Bank, Vaishali Parekh recommends three stocks to buy today — July 10
#
# Category: Negative News
# Headline: Massive Rs 2 lakh price cut on Mahindra XUV700 for a short time: Details and new pricing
#
# Category: Positive News
# Headline: Q1 result season begins: 30 companies may report over 100% growth in profit
#
# Category: Negative News
# Headline: RBI red flags 'lakhs' of accounts used for fraud and evergreening
#
# Category: Negative News
# Headline: Trade setup for 10 July: Will BANK NIFTY hold the crucial 52,000 mark on expiry day?
#
# Category: Positive News
# Headline: Stocks To Watch: Reliance Industries, Wipro, ONGC, RVNL, Mahindra & Mahindra, Bansal Wires, Emcure Pharma
#
# Category: Negative News
# Headline: F&O frenzy in equities now turning into a stampede, warns Vijay Kedia
#
# Category: Negative News
# Headline: Adani Power Unit To Sell Electricity In 20-Year Deal With Reliance Industries
#
# Category: Negative News
# Headline: Reliance Jio introduces new 'true unlimited upgrade' add-on plans amid customer backlash over tariff hikes
#
# Category: Negative News
# Headline: Why does the latest RBI jobs data show a bump up in employment?
#
# Category: Negative News
# Headline: Samsung workers form a union at TN unit, raise demands
#
# Category: Negative News
# Headline: ONGC to invest Rs 2 trillion to meet net zero carbon emission target
#
# Category: Negative News
# Headline: Trade setup for today: Top 15 things to know before the opening bell
#
# Category: Negative News
# Headline: Stocks in news: Delta Corp, Paytm, Delhivery, Mankind Pharma, JSW Steel
#
# Category: Positive News
# Headline: Union Budget 2024: Good time to push disinvestment of public banks, says SBI report
#
# Category: Negative News
# Headline: TCS Q1 result preview: From key numbers to deal pipelines-5 key things to watch in IT major's June-quarter earnings
#
# Category: Negative News
# Headline: Trade Spotlight: How should you trade JBM Auto, Ceat, Zomato, Sun Pharma, Ipca Labs, and others on Wednesday?
#
# Category: Positive News
# Headline: Kia launches five new variants of Seltos and Sonet
#
# Category: Negative News
# Headline: Yatra Online Ordered To Speed Up COVID-19 Related Pending Refunds Worth Over ₹2.5 Cr
#
# Category: Negative News
# Headline: ALMM: India’s Solar Module Manufacturing Capacity Touches 50.8 GW
#
# Category: Negative News
# Headline: Maruti Suzuki Extended Warranty: What's Covered?
#
# Category: Positive News
# Headline: Chandra Shekhar Ghosh hangs up boots as Bandhan Bank MD and CEO
#
# Category: Negative News
# Headline: All You Need To Know About FII Positions Going Into Trade On July 10
#
# Category: Positive News
# Headline: 2024-07-09 L&T wins Significant Order for Part Construction of Two Fleet Support Ships
#
# Category: Positive News
# Headline: Gold stays bid during start of Powell testimony
#
# Category: Negative News
# Headline: Jerome Powell says more good data would strengthen case for rate cuts by Federal Reserve
#
# Category: Negative News
# Headline: No information received on Quant Mutual Fund investigation: AMFI's CEO
#
# Category: Positive News
# Headline: Amazon Prime Day 2024: Early deals and discounts on electronics, gadgets, and home appliances
#
# Category: Negative News
# Headline: Raymond Demerger: Last day to buy the stock to qualify for eligibility
#
# Category: Positive News
# Headline: Mumbai-based realty firm Ashwin Sheth Group plans to float an IPO in the next 2 years, raise ₹2,000- ₹3,000 crore
#
# Category: Positive News
# Headline: Gautam Adani to start shipbuilding at Mundra port amid global demand surge
#
# Category: Positive News
# Headline: RVNL Inks MoU With Tatweer, Wins Rs 187-Crore Nagpur Metro Contract
#
# Category: Negative News
# Headline: stock market crash: Sensex crashes over 800 points, smallcaps worst hit. 5 factors brought the bears out
#
# Category: Positive News
# Headline: Stocks to watch, July 10: Angel One, Emcure Pharma, Mankind Pharma, M&M
#
# Category: Negative News
# Headline: Bullish calls on Maruti after UP's hybrid tax break sends stock to all-time high
#
# Category: Positive News
# Headline: India's Reserve Bank Says Over 40 million Jobs Created Last Year
#
# Category: Negative News
# Headline: RVNL shares rally 10% on MoU, order win; Another ₹1,408 crore block seen
#
# Category: Negative News
# Headline: Tata Harrier, Safari Price Cut By Up To Rs 1.4 Lakh - All Variants New Prices
#
# Category: Negative News
# Headline: How BSE may benefit from a SEBI proposal to curb F&O frenzy
#
# Category: Negative News
# Headline: Results play! Earnings growth to moderate for banks in Q1. Which stocks to buy?
#
# Category: Positive News
# Headline: Rajiv Bajaj To Hero MotoCorp At Bajaj CNG Bike Launch - Tiger Zinda Hain
#
# Category: Negative News
# Headline: Top Stock Recommendations: Sagar Doshi of Nuvama suggests Laurus Labs, Balrampur Chini, and Hindalco today
#
# Category: Positive News
# Headline: Kerala's own airline: Air Kerala to take off soon | Air Kerala News | Air Kerala Flight | Travel
#
# Category: Negative News
# Headline: TCS Q1 preview: June quarter likely to be softer; margin may remain under pressure
#
# Category: Positive News
# Headline: Adani Ports' Shares Inch Up On Winning Bid To Run Berth At Gujarat Port
#
# Category: Negative News
# Headline: Namita Thapar's Emcure Pharma lists at 31% premium on NSE
#
# Category: Positive News
# Headline: Gold holds positive ground ahead of Fed Chair Powell’s second testimony
#
# Category: Negative News
# Headline: Q1 Earnings Preview: Flat to 4% growth in net profit expected from Nifty pack; auto, financials, health to
#
# Category: Positive News
# Headline: Stocks To Watch: Godrej Consumer, Godrej Industries, Bajaj Finserv, Torrent Power, Container Corp, JSW Steel
#
# Category: Negative News
# Headline: CESC share price: Why the stock surged over 10% on Tuesday - Explained
#
# Category: Negative News
# Headline: HDFC Defence Fund to halt new SIP registrations from July 22
#
# Category: Positive News
# Headline: Nifty 50, Sensex today: What to expect from Indian stock market in trade on July 9
#
# Category: Negative News
# Headline: Too Many Internal Accounts Could Be Doorway To Evergreening, RBI Warns CFOs
#
# Category: Positive News
# Headline: MC Exclusive
#
# Category: Negative News
# Headline: Who is Snorting the $20 Billion Dry Powder in India?
#
# Category: Positive News
# Headline: New Toyota Fortuner Rival Coming in 2025
#
# Category: Negative News
# Headline: BofA downgrades HDFC Bank, cuts target price after 20% rally from Feb-lows
#
# Category: Negative News
# Headline: Trade Spotlight: How should you trade JBM Auto, Ceat, Zomato, Sun Pharma, Ipca Labs, and others on...
#
# Category: Negative News
# Headline: 'People Don't Purchase High-End Luxurious Cars To Suffer Discomfort' : Supreme Court Holds Mercedes Benz... - Live Law
#
# Category: Positive News
# Headline: 'Trading at 32X... risk of correction GREATEST in...' - Jefferies' market view ahead of Budget 2024
#
# Category: Deals
# Headline: IPO GMP Price Today: Rs 258 Latest Grey Market Premium! Last date subscription ALERT
#
# Category: Negative News
# Headline: Paytm In Hot Water As Bengaluru Labour Body Looks Into Allegations Of Forced Layoffs Without Pay: Report
#
# Category: Negative News
# Headline: Mazagon Dock shares correct over 10% from record highs; Cochin Shipyard, GRSE too decline
#
# Category: Negative News
# Headline: Sensex tumbles 1,000 pts intraday: Why are stock markets falling today?
#
# Category: Negative News
# Headline: Official employment data masks India's jobs problem, say economists
#
# Category: Positive News
# Headline: Auto Stocks Shift Gears: Maruti Suzuki soars on policy boost, M&M, Tata Motors lag; ‘Hybrid’ a must-have, say analysts
#
# Category: Deals
# Headline: Bansal Wire IPO listing: Shares list at 39% premium on NSE; key things to know
#
# Category: Positive News
# Headline: SEBI Committee Set To Evaluate F&O Expert Panel Recommendations On Volatility, Leverage
#
# Category: Positive News
# Headline: Gold price in India: Rates on July 10
#
# Category: Positive News
# Headline: Zomato CEO Deepinder Goyal, wife Grecia Munoz celebrate delivery giant’s 16th birthday with Gurgaon school kids
#
# Category: Negative News
# Headline: REC, PFC shares hit a new record high; Should you add or book profits?
#
# Category: Negative News
# Headline: Telecom equipment manufacturing sales cross Rs 50,000 crore milestone under PLI Scheme
#
# Category: Positive News
# Headline: Q1 result season begins: 30 companies may report over 100% growth in profit
#
# Category: Negative News
# Headline: Asian Paints hikes prices by 0.7-1% across portfolio
#
# Category: Negative News
# Headline: Weekly picks: From TVS Motor to BHEL, Motilal Oswal suggests these three stocks to buy this week
#
# Category: Negative News
# Headline: Angel One Data Breach: Investors' data leaked? Brokerage comments on reports
#
# Category: Negative News
# Headline: New Hyundai Exter Knight Edition Teased - Or Is It N Line?
#
# Category: Negative News
# Headline: Reliance Jio introduces new ’true unlimited upgrade’ add-on plans amid customer backlash over tariff hikes
#
# Category: Negative News
# Headline: Amazon Pay India bats for fair MDR on UPI payments to small merchants
#
# Category: Negative News
# Headline: Union Budget 2024-25 likely to go vocal for higher local procurement
#
# Category: Negative News
# Headline: NPCI likely to fix 1.2% interchange for credit line on UPI, issue circular next week
#
# Category: Negative News
# Headline: Buyback Alert: KDDL to repurchase shares from existing shareholders at a 12% premium
#
# Category: Negative News
# Headline: RVNL Inks MoU With IMS Consultancy For Technical And Advisory Services In Nepal
#
# Category: Negative News
# Headline: RVNL, Siemens Bag Order From Bengaluru Metro For Advanced Rail Electrification
#
# Category: Negative News
# Headline: Trade Spotlight: How should you trade Nestle, Alkem Labs, Hindustan Copper, BHEL, and others on Tuesday?
#
# Category: Positive News
# Headline: ‘Will take you to court’: Angry investor to Zerodha CEO Nikhil Kamath
#
# Category: Positive News
# Headline: Market Trading Guide: Dr. Reddy's, Eicher Motors among 6 top stock recommendations for Wednesday
#
# Category: Positive News
# Headline: Chandra Shekhar Ghosh hangs up boots as Bandhan Bank MD and CEO
#
# Category: Deals
# Headline: YES Bank’s $5 billion stake said to attract lenders from the Middle East, Japan
#
# Category: Negative News
# Headline: Microsoft quits Sam Altman's OpenAI board: ‘No longer necessary…’
#
# Category: Negative News
# Headline: Top Gainers and Losers today on 10 July, 2024: Asian Paints, SBI Life Insurance Company, Mahindra & Mahindra, Tata Steel among most active stocks; Check full list here
#
# Category: Negative News
# Headline: Share Market HIGHLIGHTS: Sensex, Nifty50 retreat from record highs amid weakness in auto, financial
#
# Category: Negative News
# Headline: No link between UP hybrid car policy and XUV 700 price cut, clarifies M&M
#
# Category: Negative News
# Headline: 2024 BYD Atto 3 Electric Launch Price 25 Lakh - 3 Variants, 521 Kms Range
#
# Category: Negative News
# Headline: EV race: Are hybrid vehicles getting in the faster lane?
#
# Category: Positive News
# Headline: Kotak Warns Of 'Crushing And Lasting Impact' Of Possible SEBI Guardrails On Derivatives Trading
#
# Category: Negative News
# Headline: Budget 2024 may propel a key element of the Modi govt's Panchamrit goals
#
# Category: Positive News
# Headline: Khadi sales rise 9.3% to Rs 6,496 crore in FY24
#
# Category: Negative News
# Headline: Grecia Munoz breaks Instagram silence months after marrying Zomato CEO Deepinder Goyal. See post
#
# Category: Positive News
# Headline: Hyundai Exter Goes Black With Knight Edition - Celebrates 1st Anniversary With 93k Sales
#
# Category: Positive News
# Headline: Adani Power Shares Jump On Energy Agreement With Reliance
#
# Category: Negative News
# Headline: 2024 TVS Apache RTR 160 Race Edition Launched - Rs 1.29 L, Sportier Design
#
# Category: Negative News
# Headline: Bajaj Freedom 125 — How does CNG tech work?
#
# Category: Positive News
# Headline: ICICI Bank, SBI among Nomura’s 4 preferred banking stocks ahead of Q1 results
#
# Category: Negative News
# Headline: Delta Corp's Share Price Plummets As Q1 Net Profit Takes Huge Hit
#
# Category: Positive News
# Headline: Accenture Acquires Cientra to Expand Silicon Design Capabilities - Newsroom
#
# Category: Positive News
# Headline: Angel One assures data integrity, denies any new leak of customer data
#
# Category: Negative News
# Headline: BEL zooms 80% YTD; should investors chase the PSU defence stock’s stellar performance?
#
# Category: Negative News
# Headline: Zepto selling dhaniya for ₹140 in Gurgaon has social media united in outrage
#
# Category: Negative News
# Headline: Nifty Auto plummets nearly 3% as M&M, Tata Motors fall sharply; Maruti Suzuki hits new record high
#
# Category: Negative News
# Headline: Equity Fund Inflows Jump by 17% In June To Over ₹40,000 Cr, Shows AMFI Data
#
# Category: Negative News
# Headline: Export duty on parboiled rice may be fixed at $100/tonne
#
# Category: Negative News
# Headline: HDFC Bank share declines after BofA downgrades stock to ‘neutral’, cuts target price
#
# Category: Positive News
# Headline: Technical View
#
# Category: Negative News
# Headline: RBI cautions banks against ‘lakhs of accounts’ used for fraudulent transactions, evergreening
#
# Category: Negative News
# Headline: Wealthy Indians can buy property and get residency in these 10 countries: Check how much it costs
#
# Category: Negative News
# Headline: Powell speech: We see current Fed policy as restrictive
#
# Category: Positive News
# Headline: Tata Curvv New Teasers Show Off-road Prowess In Thar Desert, Himalayas
#
# Category: Negative News
# Headline: Supreme Court orders Mercedes to refund ₹36 lakh for defective car - Bar & Bench
#
# Category: Negative News
# Headline: Tata Elxsi Q1 Results: Net profit falls 3% YoY to Rs 184 crore
#
# Category: Negative News
# Headline: Canara Bank plans to raise Rs 10K cr through infrastructure bonds in FY25
#
# Category: Negative News
# Headline: Top 5 index SIP mutual funds in 5 years: No. 1 fund has turned Rs 25,000 monthly SIP into Rs 31 lakh; has BEL, Trent, and HAL as its main stocks
#
# Category: Negative News
# Headline: NHPC Share Price Target till BUDGET: Check make-or-break level for PSU stock
#
# Category: Positive News
# Headline: Raymond committed to creating sustained shareholder value across businesses: Gautam Singhania
#
# Category: Negative News
# Headline: ONGC to invest ₹2 lakh cr to meet net zero emission target
#
# Category: Negative News
# Headline: Cognizant settles Wipro lawsuit against former Chief Financial Officer Jatin Dalal
#
# Category: Positive News
# Headline: M&HCV, bus sales shift up in Q1; top 4 players register 7.2 growth
#
# Category: Negative News
# Headline: Brokerages Bullish On Maruti After UP Government's Tax Waiver For Hybrid Vehicles
#
# Category: Negative News
# Headline: Bansal Wire share price falls marginally post robust listing. Should you hold or exit?
#
# Category: Negative News
# Headline: HDFC Bank share declines after BofA downgrades stock to ‘neutral’, cuts target price
#
# Category: Negative News
# Headline: Stock market today: BSE Sensex surges over 600 points to move above 80,500; Nifty50 above 24,500 as bulls
#
# Category: Positive News
# Headline: IREDA share price hits lifetime high ahead of Q1 results today. Should you buy as PSU stock jumps 25% in three days?
#
# Category: Positive News
# Headline: Stocks to watch today: TCS, Adani Wilmar, Infosys, Vodafone Idea & more
#
# Category: Positive News
# Headline: TCS Q1 FY25 earnings surprise prompts major brokerages to up target prices
#
# Category: Negative News
# Headline: CPI inflation continues to be close to 5%... it's too early to talk on rate cut: Shaktikanta Das
#
# Category: Negative News
# Headline: Quant Mutual Fund's CFO resigns amid Sebi's front-running probe
#
# Category: Positive News
# Headline: RBI allows residents to open foreign currency bank accounts within Indian jurisdiction
#
# Category: Negative News
# Headline: Stock market today: Trade setup for Nifty 50 to Q1 results today, five stocks to buy or sell on Friday — July 12
#
# Category: Positive News
# Headline: RailTel shares jump 11%, hit fresh 52 week high; multibaggers IRFC, Ircon join party with new peaks
#
# Category: Negative News
# Headline: 140 million HDFC Bank, Axis customers may face service interruption
#
# Category: Negative News
# Headline: Jio Financial Services Jumps On Receiving RBI Nod To Go From NBFC To Core Investment Company
#
# Category: Positive News
# Headline: Zomato Shares Hit All-Time High As Brokerage Raises Price Target
#
# Category: Negative News
# Headline: UP Govt’s hybrid vehicle tax waiver not for all cars - conditions apply
#
# Category: Positive News
# Headline: Stocks to buy or sell: Ponni Sugars to Mazda — Sumeet Bagadia recommends five breakout stocks today
#
# Category: Negative News
# Headline: S&P 500, Nasdaq tumble after US CPI inflation moderates; GIFT Nifty up
#
# Category: Positive News
# Headline: Zee Entertainment announces dates for board meet to consider fund raise; Stock surges 6%
#
# Category: Positive News
# Headline: Data centers to push India's power generation needs, $280 billion investment expected
#
# Category: Deals
# Headline: Reliance Jio could list at $112bn valuation, 15% upside in RIL: Jefferies
#
# Category: Negative News
# Headline: Gold Price Falls In India: Check 22 Carat Rate In Your City On July 11
#
# Category: Positive News
# Headline: Oil extends gains after US inflation data pushes Wall Street to lift Fed rate cut bets; Brent stays above $85/bbl
#
# Category: Negative News
# Headline: HCL Tech Q1 Results Preview: PAT may grow 6% YoY to Rs 3,745 crore, revenue uptick seen at 6.5%
#
# Category: Positive News
# Headline: Anand Rathi Wealth Q1 Result
#
# Category: Negative News
# Headline: Sachin Tendulkar-Backed Small Cap Stock Jumps 4% On Bagging Siemens Order
#
# Category: Positive News
# Headline: ONGC, Oil India, Selan on fire; Here's what fueled up to 13% rally today
#
# Category: Positive News
# Headline: Acer ties up with Indkal Technologies to enter Indian phone market
#
# Category: Positive News
# Headline: Gold surges above $2,400 mark as US Inflation data boosts rate-cut expectations; silver up 2.7%
#
# Category: Negative News
# Headline: Mahindra & Mahindra stock declines for second consecutive day - Is it right time to buy? Check target b...
#
# Category: Negative News
# Headline: Shortage of India-made Solar Modules Hits Projects with DCR Mandate
#
# Category: Deals
# Headline: Adani Wilmar Diversifies Portfolio With Majority Stake Acquisition In Speciality Chemicals Company
#
# Category: Negative News
# Headline: Could SEBI's new proposal unintentionally favour BSE over NSE?
#
# Category: Positive News
# Headline: BYD Introduces Affordable Atto 3 Variant With Smaller Battery Pack
#
# Category: Positive News
# Headline: Namita Thapar's emotional post on Emcure IPO listing: ‘Mirza Ghalib sums up my feelings’
#
# Category: Negative News
# Headline: Bajaj Freedom CNG Tank Filling Experience - Public Reactions Caught On Cam
#
# Category: Deals
# Headline: Brookfield to buy controlling stake in Leap Green for $550 million
#
# Category: Deals
# Headline: SJVN share price: LIC ups stake, retail shareholding rises to 12 lakh
#
# Category: Positive News
# Headline: Multibagger Small Cap Railway Stock Wins ₹432 Cr Order From Railways
#
# Category: Negative News
# Headline: iPhone and Android users beware of the fake India Post messages
#
# Category: Positive News
# Headline: Adani Realty Tops Hurun Real Estate Ranking As Most Valuable Unlisted Company
#
# Category: Negative News
# Headline: Hindustan Zinc Inks Deal To Acquire 180-MW Renewable Energy From Serentica
#
# Category: Negative News
# Headline: Four public issues to hit Dalal Street on July 12, check the details here
#
# Category: Negative News
# Headline: Nearly 70% of TCS employees return to office after variable pay is linked to attendance
#
# Category: Negative News
# Headline: Budget 2024: Remedial steps to fire up local manufacturing
#
# Category: Negative News
# Headline: Demat account additions cross 40 lakh for the fourth time in June; NSE active clients up by 3%
#
# Category: Deals
# Headline: First Abu Dhabi Bank denies interest in acquiring stake in Yes Bank: Report
#
# Category: Positive News
# Headline: Compact SUV Sales June 2024 - Creta, G Vitara, Seltos, HyRyder, Elevate, Taigun, Kushaq
#
# Category: Positive News
# Headline: Hyundai India Celebrates EXTER's First Anniversary With Launch Of EXTER Knight
#
# Category: Negative News
# Headline: ABB India Shares Under Pressure As UBS Downgrades Stock
#
# Category: Positive News
# Headline: D-Street's cooling earnings momentum set to challenge stock rally
#
# Category: Negative News
# Headline: Here's how Nvidia's chips may disrupt big fat Indian weddings
#
# Category: Negative News
# Headline: Decoding Airtel’s new Xstream Fiber bundles, seeking value with Live TV and OTT
#
# Category: Negative News
# Headline: Yes Bank shares jump 7% after an outlook upgrade from Moody's
#
# Category: Negative News
# Headline: Mutual Funds, FIIs Cut Shareholding in Bharat Electronics
#
# Category: Negative News
# Headline: Shipping Corporation of India stock jumps another 16.5%, up 40% in 3 sessions. Here's what triggered the rally
#
# Category: Negative News
# Headline: HPL Electric surges 15% on bagging Rs 2,000 crore order
#
# Category: Negative News
# Headline: Vi shareholders okay Rs 2,458 cr preferential issue to Nokia, Ericsson
#
# Category: Positive News
# Headline: Mahindra Thar 5-door Spied Again In Three New Shades, To Debut On August 15
#
# Category: Positive News
# Headline: Car Retail Sales June 2024 - Maruti, Hyundai, Tata, Mahindra, Toyota, Kia, Honda, Citroen, Jeep, BYD
#
# Category: Negative News
# Headline: 277% return in 1 year: This multibagger PSU stock in focus today - Heres why
#
# Category: Negative News
# Headline: Explainer: Vijay Kedia stock, Adani Power among over 1,000 other scrips knocked out of acceptable NSE coll
#
# Category: Negative News
# Headline: Tata Elxsi Shares In Red After Net Profit Falls, Kotak Maintains 'Sell'
#
# Category: Negative News
# Headline: BSNL presence crucial to keep in check private telcos’ monopolistic pricing: BMS to PM Modi
#
# Category: Negative News
# Headline: Analyst suggests buying this multi-bagger defence PSU stock before Budget 2024
#
# Category: Negative News
# ...
#
# Category: Positive News
# Headline: Bajaj Auto Shares In Green Ahead Of Q1 Results: Here's What To Expect
#
# Category: Negative News
# Headline: Loan default: NCLT declares GVK power & infra bankrupt
#
# Category: Negative News
# Headline: IREDA share price dips 5% as Philip Capital slaps 'sell' tag. Opportunity for bottom fishing?
#
# Category: Positive News
# Headline: L&T, Tata Tech among 7 stocks to bet on ahead of Union Budget
#
# Category: Positive News
# Headline: Jio Financial Services Q1 Results Live : profit rise by 3354.67% YOY
#
# Category: Negative News
# Headline: NCLT admits BCCI’s plea seeking insolvency proceedings against Byju’s
#
# Category: Positive News
# Headline: Muharram: Public holiday in Kerala tomorrow | Onmanorama Muharram 2024 Kerala
#
# Category: Negative News
# Headline: Vodafone Idea shares jump nearly 6% as SC agrees to consider plea on AGR dues
#
# Category: Positive News
# Headline: India’s IT sector to ramp up hiring amid rising demand for services
#
# Category: Negative News
# Headline: Gold sticks to intraday gains, bulls seem non-committed amid risk-on/USD uptick
#
# Category: Positive News
# Headline: AO Smith buys HUL's Pureit business in India for ₹601 crore
#
# Category: Positive News
# Headline: MTNL interest obligations on bonds to be honoured by government: Sources
#
# Category: Negative News
# Headline: IOC's green hydrogen project sees sparse bids amidst industry concerns: Report
#
# Category: Positive News
# Headline: Zomato's M-Cap Surges To ₹2 Lakh Cr, Now More Valuable Than Tech Mahindra, Tata Consumer
#
# Category: Positive News
# Headline: Sembcorp Industries sets ball rolling for Rs 36,000 crore TN project
#
# Category: Positive News
# Headline: Bajaj Auto Q1 Results: Cons PAT jumps 18% YoY to Rs 1,942 crore, revenue rises 16%
#
# Category: Negative News
# Headline: Hindustan Unilever Shares Gain On Sale Of Pureit Business
#
# Category: Negative News
# Headline: Byju's Crisis: NCLT admits BCCI's petition seeking insolvency proceedings, cricketing body aims to recover ₹158 crore
#
# Category: Negative News
# Headline: Job Alert: Elon Mask announces Tesla, xAI are looking to hire networking engineers, technicians
#
# Category: Positive News
# Headline: Budget 24 Trading Strategy: Three stocks that have the perfect pitch for trading on Budget Day
#
# Category: Negative News
# Headline: Jio Financial Q1 Results: Profit Stays Flat On Lower Interest Income
#
# Category: Positive News
# Headline: HDFC Life Q1 Results: Net profit rises 15% YoY to Rs 477 crore
#
# Category: Positive News
# Headline: Bill Gates-backed startup makes butter out of air, claims it tastes really good: 'Like the real thing'
#
# Category: Negative News
# Headline: Swiggy, Zomato hike platform fees; online food delivery to cost more
#
# Category: Negative News
# Headline: Why Tata Motors Shares Shot Up Sharply On Tuesday
#
# Category: Negative News
# Headline: SBI Amrit Kalash FD: SBI FD that offers highest interest rate; know return values of Rs 5 lakh, Rs 10 lakh...
#
# Category: Positive News
# Headline: Exclusive! Tata Curvv EV unofficial bookings open
#
# Category: Negative News
# Headline: Tata Steel Q1 PAT seen up 37.7% YoY to Rs. 870 cr: Prabhudas Lilladher
#
# Category: Negative News
# Headline: Muharram bank holiday July 2024: Banks in these states will be closed on Wednesday, July 17
#
# Category: Positive News
# Headline: Dolly Khanna portfolio: Multibagger stock Chennai Petroleum Corporation hits record high logging 14% intraday rally
#
# Category: Negative News
# Headline: Gold Rate Today Falls In India: Check 22 Carat Price In Your City On July 15
#
# Category: Negative News
# Headline: SpiceJet shares up over 8 percent in anticipation of much-delayed financial results
#
# Category: Negative News
# Headline: Infosys Q1 Earnings Preview: Revenue, margin may return to growth, but net profit set to fall from...
#
# Category: Positive News
# Headline: Brokerages Impressed With HDFC AMC's Q1 Show, Maintain 'Buy'
#
# Category: Negative News
# Headline: Big movers on D-Street: What should investors do with Aurobindo Pharma, Tanla Platforms and IDBI Bank?
#
# Category: Negative News
# Headline: Mahindra Thar 5-Door Wheels On 3-Door Model - Aftermarket Fitment Before Launch
#
# Category: Positive News
# Headline: Gujarati family takes 73-year-old car on road trip from Ahmedabad to London. Watch
#
# Category: Negative News
# Headline: Amazon Prime Day deals revealed: Big discount on iPhone 13, OnePlus Nord CE 4, Poco M6, and more
#
# Category: Positive News
# Headline: ‘Godman’ builds temple at 16k feet on Uttarakhand glacier, probe on
#
# Category: Positive News
# Headline: Bajaj Auto, Asian Paints, VBL: Top picks by Jigar S Patel of Anand Rathi
#
# Category: Negative News
# Headline: Law tribunal admits BCCI's plea seeking insolvency process against Byju's
#
# Category: Negative News
# Headline: Bank Holiday on July 16: Are banks closed today for Harela? Check details here
#
# Category: Positive News
# Headline: Bajaj Auto Q1 Results: Cons PAT jumps 18% YoY to Rs 1,942 crore, revenue rises 16%
#
# Category: Negative News
# Headline: Elon Musk claims X recorded ‘all-time high’ of 417 billion user seconds globally on platform on July 15
#
# Category: Positive News
# Headline: Vedanta Shares — What lies ahead for Anil Agarwal's firm post ~₹7,000 crore QIP
#
# Category: Negative News
# Headline: Sahaj Solar IPO allotment likely to be fixed today. Latest GMP, steps to check allotment status
#
# Category: Negative News
# Headline: Swiggy, Zomato may start alcohol delivery in some states: Report
#
# Category: Negative News
# Headline: CESC Subsidiary Purvah Green To Supply, Maintain Wind Turbines For Suzlon Energy
#
# Category: Negative News
# Headline: Here's why RVNL shares are falling in trade today; Details here
#
# Category: Negative News
# Headline: ICICI Sec Upbeat About Defence Stocks, Picks Private Players Over PSUs
#
# Category: Negative News
# Headline: Ethereum ETF Launch Date Confirmed: SEC Greenlights Trading for July 23
#
# Category: Negative News
# Headline: Byju’s, once valued at $22 billion, faces insolvency proceedings
#
# Category: Positive News
# Headline: Gold and silver prices today on 16-07-2024: Check latest rates in your city
#
# Category: Negative News
# Headline: Kerala likely to launch online alcohol delivery via Swiggy, Zomato | Onmanorama News
#
# Category: Negative News
# Headline: Paytm gets warning from Sebi for old transactions with banking unit
#
# Category: Negative News
# Headline: Wednesday Bank Holiday: Banks will remain closed on Wednesday too! Know why RBI has given holiday to all banks
#
# Category: Negative News
# Headline: Shocking Twist To Hybrid Car Price Drop: Union Govt Vs State Govt
#
# Category: Positive News
# Headline: Gold (XAU/USD) - Ready to Print a New All-Time High, Latest Sentiment Analysis
#
# Category: Negative News
# Headline: Garden Reach Shipbuilders Shares Jump 3% After Bagging ₹840 Cr Order
#
# Category: Negative News
# Headline: Buy Varun Beverages; target of Rs 1900: Motilal Oswal
#
# Category: Positive News
# Headline: Indian stock market: 7 key things that changed for market overnight - Gift Nifty, Dow Jones record close to oil prices
#
# Category: Negative News
# Headline: Kia EV6 Recalled In India Affecting 1,138 Units - Same Reason As Ioniq 5
#
# Category: Negative News
# Headline: Despite filing ITR successfully tax refund may not be credited into your bank account due to this issue
#
# Category: Negative News
# Headline: Adani Looks To Add Insolvent Jaypee Group Assets To Arsenal Amid War For Cement Market Share: Report
#
# Category: Positive News
# Headline: India’s IT sector to ramp up hiring amid rising demand for services
#
# Category: Positive News
# Headline: Angel One stock gains after profit, revenue grows in Q1FY25
#
# Category: Negative News
# Headline: Rs 1.8 lakh crore boom! Will defence stocks live up to Budget hype?
#
# Category: Negative News
# Headline: Camlin founder Subhash Dandekar dies
#
# Category: Positive News
# Headline: Sebi invites comments on proposal for new asset class bridging between mutual funds and PMS
#
# Category: Negative News
# Headline: FAME 3 scheme in final stages, unlikely to be in budget, says Heavy Industries Minister
#
# Category: Positive News
# Headline: L&T Finance Q1 Results: Net profit rises 29% at ₹686 crore
#
# Category: Positive News
# Headline: Budget 2024: Ashok Leyland, Siemens, Ultratech Cement, NCC among top 13 budget picks by Anand Rathi
#
# Category: Positive News
# Headline: Tata Curvv And Curvv EV To Debut On This Date
#
# Category: Positive News
# Headline: Gold (XAU/USD) - Ready to Print a New All-Time High, Latest Sentiment Analysis
#
# Category: Positive News
# Headline: Staying with quality pays in long term wealth creation: 5 midcap stocks from different sectors with potent
#
# Category: Negative News
# Headline: Several states including Delhi, Karnataka, Tamil Nadu may get liquor home delivery: Report
#
# Category: Positive News
# Headline: Bharti Airtel Foundation announces ₹100 crore scholarship for tech students
#
# Category: Negative News
# Headline: How To Check Sahaj Solar IPO Allotment Status
#
# Category: Positive News
# Headline: Wall Street today: US stocks edge higher after strong retail sales data, robust earnings
#
# Category: Positive News
# Headline: UP caps incentive for electric cars, revised notification deepens suspense over hybrids
#
# Category: Positive News
# Headline: TCS HR chief Milind Lakkad says linking variable pay with bonus not to punish staff, aimed to boost ‘return to office’
#
# Category: Negative News
# Headline: Union Budget 2024: Overseas credit card spending above ₹7 lakh may be taxed 20%
#
# Category: Positive News
# Headline: Sectoral, thematic funds catching investor fancy
#
# Category: Negative News
# Headline: Swiggy, Zomato Might Soon Deliver Alcohol In These States: Report
#
# Category: Deals
# Headline: Ola Electric IPO pricing likely at about 25% lower than private valuation of $5.4 billion: sources
#
# Category: Positive News
# Headline: IMF raises India's GDP forecast to 7% for 2024-25
#
# Category: Negative News
# Headline: Subhash Dandekar, founder of Camlin, is no more
#
# Category: Positive News
# Headline: Bank of Baroda, Bank of Maharashtra launch special fixed deposit schemes. Details here
#
# Category: Negative News
# Headline: Breaking: Gold hits record high as rate cut hopes surge, XAU/USD breaches $2,450
#
# Category: Negative News
# Headline: Stocks to buy: KEC International, TCS among top four picks by SMC Global for this week, eyes 14-18% upside at TP
#
# Category: Negative News
# Headline: Swiggy, Zomato Might Soon Deliver Alcohol In These States: Report
#
# Category: Negative News
# Headline: Stock market holiday: Is Indian stock market shut tomorrow?
#
# Category: Positive News
# Headline: Chennai Petroleum Shares Soar 14% As Stock Approaches Record Date For ₹55 Dividend
#
# Category: Positive News
# Headline: What HCLTech CEO Vijayakumar said on linking variable pay to office attendance
#
# Category: Negative News
# Headline: Infosys shares cross Rs 1,731 level to scale fresh 52-week high; analysts await Q1 results due on Thursday
#
# Category: Negative News
# Headline: Garden Reach Shipbuilders bags ₹840 crore order from National Centre for Polar and Ocean Research
#
# Category: Positive News
# Headline: Zomato makes a new high after 20% fee hike
#
# Category: Negative News
# Headline: Gainers & Losers: Stocks that moved the most on July 16
#
# Category: Negative News
# Headline: Exclusive: Crisis Hit BYJU’S Locked Out Of Over 100 Tuition Centres Over Unpaid Rent
#
# Category: Negative News
# Headline: Buy Varun Beverages; target of Rs 1900: Motilal Oswal
#
# Category: Negative News
# Headline: Ex Rolls-Royce Head Designer Stabbed To Death In $3 Million Germany Mansion
#
# Category: Negative News
# Headline: Ex-billionaire loses control of Byju’s in blow to India's tech ambitions
#
# Category: Negative News
# Headline: US Market: Dow Jones gains over 740 points, Russell 2000 small-cap index rise on rate cut bets
#
# Category: Positive News
# Headline: IMF raises India’s FY25 growth forecast upward to 7%
#
# Category: Negative News
# Headline: SEBI mulls new asset class to fill gap between mutual funds and PMS
#
# Category: Positive News
# Headline: BREAKING: Royal Enfield Guerrilla 450 Launched At Rs 2,39,000
#
# Category: Negative News
# Headline: Tata Curvv SUV Debut On 19th July – Can It Break Creta’s Dominance?
#
# Category: Negative News
# Headline: Indian banks have 'special plans' for offering higher deposit rates
#
# Category: Positive News
# Headline: Q1 results today: Asian Paints, LTIMindtree, Hathway Cable & Datacom among 22 companies to announce earnings on July 17
#
# Category: Negative News
# Headline: Gold retreats from all-time high amid profit-taking, potential downside seems limited
#
# Category: Positive News
# Headline: Zee board approves raising up to $239 mn through 10-yr foreign currency convertible bonds
#
# Category: Positive News
# Headline: Tata Power sets ₹20,000 crore investment target for FY25, to drive renewable energy expansion
#
# Category: Positive News
# Headline: Hyundai Copies Tata Motors Success Mantra
#
# Category: Positive News
# Headline: Gold prices reach all-time high in Hyderabad
#
# Category: Negative News
# Headline: Is HDFC Life a new competitor to the mutual fund industry?
#
# Category: Positive News
# Headline: Indian aviation reports best-ever first half in 2024; IndiGo, Tata group airlines fly high; SpiceJet biggest loser
#
# Category: Negative News
# Headline: Fraud tag on loans only after hearing borrowers: RBI to banks
#
# Category: Negative News
# Headline: Jupiter Wagons eyes 20-fold jump in exports to ₹2,000 crore by FY26-end
#
# Category: Negative News
# Headline: Bajaj Auto Shares In Green As Net Profit Jumps 19% To ₹1,988 Cr
#
# Category: Negative News
# Headline: PSU stock: Planning to buy IREDA shares? Know brokerages views on renewable energy stock
#
# Category: Positive News
# Headline: Hindustan Aeronautics: On a high-altitude orbit
#
# Category: Positive News
# Headline: These 6 energy stocks hit fresh 52-week highs; rallied up to 30% in a month
#
# Category: Negative News
# Headline: Dairy Dreams: Milky Mist eyes IPO at Rs 20,000 crore valuation months after WestBridge talks fall through
#
# Category: Deals
# Headline: FIIs & DIIs collectively buy 6.66 per cent stake in this multibagger airline company: Stock under Rs 60 jumped 9.85 per cent post turnaround net profit in Q4FY24
#
# Category: Deals
# Headline: Swiggy investor keeps valuation unchanged ahead of IPO as Zomato retains rich tag
#
# Category: Negative News
# Headline: Tech View: Nifty forms another Doji candle. Here’s how to trade on Thursday
#
# Category: Positive News
# Headline: Modern, Bold and Muscular: Škoda Auto India shares design glimpse of all-new compact SUV
#
# Category: Negative News
# Headline: F&O trading: Sebi to discuss ways to tighten the screws on retail speculation
#
# Category: Negative News
# Headline: Adani Enterprises to buy 77.5% of Coredge.io parent for ₹20,000 per share
#
# Category: Negative News
# Headline: NSE-listed media stock hits 7-year high after net profit rises 49% in Q1FY25, ₹7 dividend declared; Buy or sell?
#
# Category: Negative News
# Headline: Multibagger stock under Rs 500: Rs 1 lakh investment grows to Rs 3 lakh in 1 yr! Q1 FY25 PAT zooms 42%
#
# Category: Negative News
# Headline: Watch: Deepinder Goyal in splits as comedian roasts Zomato’s platform fee, rain surge
#
# Category: Negative News
# Headline: NCLT holds GVK Power and Infra bankrupt, admits insolvency petition by ICICI Bank - Bar & Bench
#
# Category: Positive News
# Headline: Pace, Hero, ACME, JSW Win SECI’s 1.2 GW Solar Plus Storage Auction
#
# Category: Negative News
# Headline: Four Unexplored Indian Basins May Hold More Oil Than The Permian
#
# Category: Negative News
# Headline: IRDAI imposes Rs 2 crore penalty on Bajaj Finance for violating regulations
#
# Category: Negative News
# Headline: Camlin Founder Subhash Dandekar Passes Away At 86
#
# Category: Negative News
# Headline: Exclusive: Crisis-Hit BYJU’S Locked Out Of Over 100 Tuition Centres Over Unpaid Rent
#
# Category: Negative News
# Headline: Stock Radar: Jio Financial, Angel One, Unichem Labs, HUL, Vedanta in focus on Tuesday

# %%
import textblob

# %%
textblob.Word("Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate")
# Out:
# 'Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate'

# %%
import spacy

# %%
import nltk

# %%
from nltk.corpus import brown
brown.categories()
['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies',
'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance',
'science_fiction']
brown.words(categories='news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
import nltk

# %%
nltk.corpus.brown.words(categories = "news")
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('stocks')
# Out:
# af in is all health more now knowledge dark towns the said of that and
# for possible this two date

# %%
import nltk
from nltk.corpus import brown

nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\modza\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
news_texts = brown.words(categories='news')

# %%
print(news_texts[:100])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
news_text = ' '.join(news_texts)
print(news_text[:500])
# Out:
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted . The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to invest

# %%
news_sentences = brown.sents(categories='news')
for sentence in news_sentences[:5]:
    print(' '.join(sentence))
# Out:
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .
# The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted .
# The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .
# `` Only a relative handful of such reports was received '' , the jury said , `` considering the widespread interest in the election , the number of voters and the size of this city '' .
# The jury said it did find that many of Georgia's registration and election laws `` are outmoded or inadequate and often ambiguous '' .

# %%
import nltk
from nltk.corpus import brown

# Download the Brown corpus
nltk.download('brown')

# Access the news category
news_texts = brown.words(categories='news')

# Print the first 100 words
print(news_texts[:100])

# Convert to a string and print the first 500 characters
news_text = ' '.join(news_texts)
print(news_text[:500])

# Get sentences instead of words
news_sentences = brown.sents(categories='news')
for sentence in news_sentences[:5]:
    print(' '.join(sentence))

# Tokenization
from nltk.tokenize import word_tokenize
news_words = word_tokenize(news_text)

# Frequency Distribution
from nltk.probability import FreqDist
fdist = FreqDist(news_words)
print(fdist.most_common(10))
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\modza\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted . The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to invest
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .
# The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted .
# The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .
# `` Only a relative handful of such reports was received '' , the jury said , `` considering the widespread interest in the election , the number of voters and the size of this city '' .
# The jury said it did find that many of Georgia's registration and election laws `` are outmoded or inadequate and often ambiguous '' .
# [('the', 5580), (',', 5188), ('.', 4180), ('of', 2849), ('and', 2146), ('to', 2116), ('a', 1993), ('in', 1893), ('``', 1434), ('for', 943)]

# %% [markdown]
# text = nltk.word_tokenize("Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate")
# nltk.pos_tag(text)

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("Data_for_semantic_analysis.csv",index_col = 0)
df.head()
# Out:
#                                             headline          news_category  \
# 0  'Will explore legal options': Kotak Bank probi...  Company Business News
# 1  ONGC Leads Nifty Gainers With 3% Gain As Marke...                    NaN
# 2  SBI wants tax parity on bank FDs with mutual f...                    NaN
# 3  Rs 85,000 Crore Order Book: Railway Infra Comp...                    NaN
# 4  Trade Setup For July 9: Investors Await Q1 Ear...                    NaN
#
#                                 org
# 0                              Mint
# 1                    Benzinga India
# 2                The Economic Times
# 3   Dalal Street Investment Journal
# 4                       NDTV Profit

# %%
df.headline[0]
# Out:
# "'Will explore legal options': Kotak Bank probing if Kingdon Capital hid Hindenburg Research links "

# %%
import nltk
from nltk.corpus import brown
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('brown')

# Sample headlines


# Function to preprocess text
def preprocess(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans(, , string.punctuation))
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return tokens

# Preprocess headlines
preprocessed_headlines = [preprocess(headline) for headline in df.headline]
print(preprocessed_headlines)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\modza\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\modza\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\modza\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [['explore', 'legal', 'options', 'kotak', 'bank', 'probing', 'kingdon', 'capital', 'hid', 'hindenburg', 'research', 'links'], ['ongc', 'leads', 'nifty', 'gainers', '3', 'gain', 'market', 'ends', 'flat', 'monday'], ['sbi', 'wants', 'tax', 'parity', 'bank', 'fds', 'mutual', 'funds', 'equity', 'markets', 'budget'], ['rs', '85000', 'crore', 'order', 'book', 'railway', 'infra', 'company', 'hits', 'fresh', '52week', 'high', 'heavy', 'volumes', 'stock', 'gains', '370', 'per', 'cent', '1', 'year'], ['trade', 'setup', 'july', '9', 'investors', 'await', 'q1', 'earnings', 'nifty', 'faces', 'key', 'resistance', 'levels'], ['ola', 'replaces', 'google', 'maps', 'inhouse', '‘', 'ola', 'maps', '’', 'announces', 'api', 'developers'], ['tata', 'motors', 'q1', 'update', 'global', 'wholesales', 'increase', '2', 'yoy', 'stock', 'jumps'], ['kia', 'india', 'introduces', 'new', 'variants', 'seltos', 'sonet'], ['liver', 'doc', 'slams', 'nikhil', 'kamath', 'glorifying', 'business', 'alcohol', 'podcast', 'crime'], ['lt', 'enhances', 'renewables', 'portfolio', 'finalises', 'mega', 'orders', 'solar', 'plants', 'middle', 'east'], ['adani', 'wilmar', 'shares', 'jump', '4', 'despite', 'weak', 'stock', 'market', 'trends', 'steam', 'left'], ['blackstone', 'advanced', 'talks', 'controlling', 'stake', 'haldirams'], ['emcure', 'pharma', 'ipo', 'allotment', 'status', 'check', 'stepbystep', 'guide'], ['titan', 'gets', 'downgrade', 'street', 'turns', 'cautious', 'post', 'q1', 'business', 'update'], ['bajaj', 'freedom', '125', 'top', '10', 'stats', 'world', '’', 'first', 'cng', 'motorcycle'], ['zinka', 'logistics', 'headed', '₹550', 'cr', 'ipo', 'files', 'prospectus'], ['brightcom', 'group', 'bohra', 'industries', 'others', 'hit', '52', 'week', 'low', 'today', 'check', 'full', 'list'], ['3', 'new', 'jio', '5g', 'true', 'unlimited', 'upgrade', 'plans', 'available', 'get'], ['retail', 'investors', 'key', 'force', 'behind', 'markets', 'stellar', 'performance', 'report'], ['nifty', 'technical', 'charts', 'stay', 'course', 'alert'], ['ashish', 'kacholia', 'backed', 'small', 'cap', 'stock', 'hits', 'alltime', 'high', 'bagging', '₹1850', 'cr', 'order'], ['apple', 'may', 'revive', 'plans', 'make', 'ipads', 'india', 'eyes', 'pune', 'airpod', 'cases'], ['paytm', 'stock', 'zooms', '9', 'vijay', 'shekhar', 'sharma', 'aims', '100', 'billion', 'valuation'], ['top', 'gainers', 'losers', 'today', '8', 'july', '2024', 'oil', 'natural', 'gas', 'corporation', 'itc', 'divis', 'laboratories', 'titan', 'company', 'among', 'active', 'stocks', 'check', 'full', 'list'], ['sjvn', 'share', 'price', 'target', '2024', 'rs', '1', 'lakh', 'became', 'rs', '3', 'lakh', '1', 'yr', 'time', 'buy', 'psu', 'stock', 'gains'], ['nhpc', 'shares', 'extend', 'gains', '4th', 'day', 'brokerage', 'issues', 'buy', 'call'], ['toyota', 'dealer', 'offers', '100', 'road', 'tax', 'waiver', 'hybrids', 'innova', 'hycross', 'hyryder', 'camry', 'rs', '44'], ['bansal', 'wire', 'ipo', 'allotment', 'finalised', 'today', 'latest', 'gmp', 'stepbystep', 'guide', 'check', 'status'], ['housing', 'prices', 'ncr', 'mmr', 'surge', '49', '5', 'years', 'unsold', 'inventory', 'plunges', 'anarock'], ['gold', 'price', 'india', 'rates', 'july', '8'], ['maruti', 'suzuki', 'dispatch', 'via', 'indian', 'railways', 'cross', 'record', '20', 'lakh', 'vehicles'], ['heatwave', 'monsoon', 'spur', 'infection', 'surge', 'augmentin', 'liv', '52', 'electral', 'sales', 'rise', 'june'], ['pc', 'jewellers', 'gets', 'pnb', 'clearance', 'onetime', 'settlement', 'outstanding', 'dues'], ['signature', 'global', 'reports', 'strong', 'q1', 'fy25', 'performance', 'amid', 'real', 'estate', 'sector', 'challenges'], ['patel', 'engineering', 'share', 'price', 'tanks', '11', 'chairman', 'md', 'rupen', 'patel', 'passes', 'away'], ['irfc', 'shares', 'surge', '9', 'record', 'high', 'stock', 'reach', '₹250'], ['top', '10', 'suvs', 'june', '2024', 'punch', 'creta', 'brezza', 'scorpio', 'venue', 'sonet', 'g', 'vitara'], ['tata', 'curvv', 'ev', 'teased', 'ahead', 'official' ...

# %%
from nltk.probability import FreqDist

# Access the news category from the Brown corpus
news_words = brown.words(categories='news')

# Preprocess Brown news words
preprocessed_news_words = [preprocess(word) for word in news_words]

# Flatten the list of lists
preprocessed_news_words = [item for sublist in preprocessed_news_words for item in sublist]

# Calculate frequency distribution for Brown news and your headlines
news_fdist = FreqDist(preprocessed_news_words)
headline_fdist = FreqDist([word for headline in preprocessed_headlines for word in df.headline])

# Compare the most common words
print("Most common words in Brown news corpus:", news_fdist.most_common(10))
print("Most common words in your headlines:", headline_fdist.most_common(10))
# Out:
# Most common words in Brown news corpus: [('said', 406), ('mrs', 254), ('would', 246), ('new', 241), ('one', 213), ('last', 177), ('two', 174), ('mr', 170), ('first', 158), ('state', 153)]
# Most common words in your headlines: [('SJVN share price target 2024: Rs 1 lakh became Rs 3 lakh in 1 yr! Time to BUY PSU stock for more gains? ', 2158), ("Ratan Tata's company earns Rs 38000 crore in 5 days, becomes biggest... ", 2158), ('MCX technical glitch: Commodity trading begins at 10 AM after one hour delay ', 2158), ('Wheel falls off United Airlines Boeing moments after takeoff from LA airport: Watch ', 2158), ('Stocks to buy or sell: RVNL, RCF to Alembic — Sumeet Bagadia recommends five breakout stocks today ', 2158), ('BlackRock buys 4.55 mn shares of Swan Energy worth Rs 304 cr via block deal ', 2158), ('Zerodha glitch: Man explains how he lost Rs 10 lakh, seeks help ', 2158), ('Ducati Hypermotard 698 Mono Launch Price Rs 16.5 Lakh - RVE Arrival Later ', 2158), ('Trade setup for today: Top 15 things to know before the opening bell ', 2158), ('MC Exclusive ', 2158)]

# %%
from nltk import NaiveBayesClassifier, classify
from nltk.classify import apply_features

# Create labeled feature sets for training
def headline_features(words):
    return {word: True for word in words}

# Create labeled data from Brown corpus
brown_news = [(headline_features(brown.words(fileid)), 'news') for fileid in brown.fileids(categories='news')]

# Split into training and test sets
train_set = apply_features(headline_features, brown_news[:400])
test_set = apply_features(headline_features, brown_news[400:])

# Train Naive Bayes classifier
classifier = NaiveBayesClassifier.train(train_set)

# Test classifier
accuracy = classify.accuracy(classifier, test_set)
print("Classifier accuracy:", accuracy)

# Classify new headlines
for headline in preprocessed_headlines:
    print(f"Headline: {' '.join(headline)}")
    print("Category:", classifier.classify(headline_features(headline)))
# Out:
# Classifier accuracy: 0
# Headline: explore legal options kotak bank probing kingdon capital hid hindenburg research links
# Category: news
# Headline: ongc leads nifty gainers 3 gain market ends flat monday
# Category: news
# Headline: sbi wants tax parity bank fds mutual funds equity markets budget
# Category: news
# Headline: rs 85000 crore order book railway infra company hits fresh 52week high heavy volumes stock gains 370 per cent 1 year
# Category: news
# Headline: trade setup july 9 investors await q1 earnings nifty faces key resistance levels
# Category: news
# Headline: ola replaces google maps inhouse ‘ ola maps ’ announces api developers
# Category: news
# Headline: tata motors q1 update global wholesales increase 2 yoy stock jumps
# Category: news
# Headline: kia india introduces new variants seltos sonet
# Category: news
# Headline: liver doc slams nikhil kamath glorifying business alcohol podcast crime
# Category: news
# Headline: lt enhances renewables portfolio finalises mega orders solar plants middle east
# Category: news
# Headline: adani wilmar shares jump 4 despite weak stock market trends steam left
# Category: news
# Headline: blackstone advanced talks controlling stake haldirams
# Category: news
# Headline: emcure pharma ipo allotment status check stepbystep guide
# Category: news
# Headline: titan gets downgrade street turns cautious post q1 business update
# Category: news
# Headline: bajaj freedom 125 top 10 stats world ’ first cng motorcycle
# Category: news
# Headline: zinka logistics headed ₹550 cr ipo files prospectus
# Category: news
# Headline: brightcom group bohra industries others hit 52 week low today check full list
# Category: news
# Headline: 3 new jio 5g true unlimited upgrade plans available get
# Category: news
# Headline: retail investors key force behind markets stellar performance report
# Category: news
# Headline: nifty technical charts stay course alert
# Category: news
# Headline: ashish kacholia backed small cap stock hits alltime high bagging ₹1850 cr order
# Category: news
# Headline: apple may revive plans make ipads india eyes pune airpod cases
# Category: news
# Headline: paytm stock zooms 9 vijay shekhar sharma aims 100 billion valuation
# Category: news
# Headline: top gainers losers today 8 july 2024 oil natural gas corporation itc divis laboratories titan company among active stocks check full list
# Category: news
# Headline: sjvn share price target 2024 rs 1 lakh became rs 3 lakh 1 yr time buy psu stock gains
# Category: news
# Headline: nhpc shares extend gains 4th day brokerage issues buy call
# Category: news
# Headline: toyota dealer offers 100 road tax waiver hybrids innova hycross hyryder camry rs 44
# Category: news
# Headline: bansal wire ipo allotment finalised today latest gmp stepbystep guide check status
# Category: news
# Headline: housing prices ncr mmr surge 49 5 years unsold inventory plunges anarock
# Category: news
# Headline: gold price india rates july 8
# Category: news
# Headline: maruti suzuki dispatch via indian railways cross record 20 lakh vehicles
# Category: news
# Headline: heatwave monsoon spur infection surge augmentin liv 52 electral sales rise june
# Category: news
# Headline: pc jewellers gets pnb clearance onetime settlement outstanding dues
# Category: news
# Headline: signature global reports strong q1 fy25 performance amid real estate sector challenges
# Category: news
# Headline: patel engineering share price tanks 11 chairman md rupen patel passes away
# Category: news
# Headline: irfc shares surge 9 record high stock reach ₹250
# Category: news
# Headline: top 10 suvs june 2024 punch creta brezza scorpio venue sonet g vitara
# Category: news
# Headline: tata curvv ev teased ahead official launch check details
# Category: news
# Headline: stocks news nykaa adani wilmar titan bandhan bank indusind bank marico dabur
# Category: news
# Headline: ‘ technocolonialism ’ bhavish aggarwal likens tech giants east india company says 20 global data india…
# Category: news
# Headline: ‘ ather sht marketing but… ’ nikhil kamath reveals didnt get discount ev scooter
# Category: news
# Headline: new private investment plans slumped 20year low q1
# Category: news
# Headline: nestle india announces first interim dividend fy25 check amount dividend payment date etc
# Category: news
# Headline: industry experts predict favourable outlook auto industry twowheelers expected lead
# Category: news
# Headline: bitcoin price today slips 57k mt gox jitters rattle crypto investingcom
# Category: news
# Headline: option strategy day
# Category: news
# Headline: q1 fy25 earnings five factors watch
# Category: news
# Headline: ratan tatas company earns rs 38000 crore 5 days becomes biggest
# Category: news
# Headline: nykaa share price overcomes early jitters trade higher strong q1 update
# Category: news
# Headline: 6500 samsung workers walk assembly lines pay vacation time
# Category: news
# Headline: gold declines trump effect pushes yields
# Category: news
# Headline: stocks buy ongc tvs motor irfc among 10 stocks may rise 621 next 34 weeks say analysts
# Category: news
# Headline: au small finance bank shares tumble 4 total deposits decline qoq
# Category: news
# Headline: adani green plans 9 billion infrastructure spend green hydrogen phase one report
# Category: news
# Headline: stocks buy sell shilpa medicare shalby — sumeet bagadia recommends five breakout stocks
# Category: news
# Headline: tomato rates soar centre looks south new stock
# Category: news
# Headline: buy exit — paytm shares 14 two sessions
# Category: news
# Headline: bank baroda shares focus q1 business update investors
# Category: news
# Headline: ondc logs 995 million transactions june retail category hits 6 million
# Category: news
# Headline: delhi hc releases rs 80 crore security ashneer grover madhuri jain return india us
# Category: news
# Headline: tata steel shares remain flat production delivery update
# Category: news
# Headline: yes bank shares market trading guide yes bank inox wind among 5 stock recommendations monday stock ideas
# Category: news
# Headline: 8 diet fitness tips borrow nita ambani
# Category: news
# Headline: air india ’ first airbus aircraft new livery lands delhi
# Category: news
# Headline: stock market today bandhan bank gnfc piramal enterprises among 6 stocks fo ban list july 8
# Category: news
# Headline: ireda shares rise 8 hit record high analyst sees upside levels ₹270
# Category: news
# Headline: mazagon dock cochin shipyard garden reach shares run much soon
# Category: news
# Headline: deposit grows slower loan many banks june quarter fy25
# Category: news
# Headline: maruti nexa july 2024 offers part 1get discounts rs 25 lakh
# Category: news
# Headline: healthcare focused fintech startup carefi raises 26 mn
# Category: news
# Headline: reports 51 stake sale factually incorrect says yes bank shares climb
# Category: news
# Headline: maruti shares get boost waives registration fees hybrid cars
# Category: news
# Headline: indian stock market 6 key things changed market overnight gift nifty us treasury yields gold rate
# Category: news
# Headline: natural gas oil forecast wti slips 83 selloff ahead
# Category: news
# Headline: rvnl shares see ₹827 crore block deal second two days stock crosses ₹600
# Category: news
# Headline: mcx technical glitch commodity trading begins 10 one hour delay
# Category: news
# Headline: zerodhas nikhil kamath says invested ₹400 crore liquor company ‘ never spoken publicly ’
# Category: news
# Headline: stocks news jupiter wagons nestle railtel bandhan bank godrej consumer pg electropast
# Category: news
# Headline: tata motors global wholesale volumes rise 2 q1 passenger vehicles segment sees dip
# Category: news
# Headline: kia introduces 5 new trims seltos sonet details inside
# Category: news
# Headline: bajaj autos cng bike bold move customer adoption concern analysts
# Category: news
# Headline: emcure pharma ipo allotment – check allotment ipo gmp listing date
# Category: news
# Headline: kotak mahindra bank ponders whether kingdon capital misrepresented connection hindenburg
# Category: news
# Headline: titan stock slumps 4 jpmorgan downgrade following weak q1 biz update
# Category: news
# Headline: q1 results week tcs hcltech avenue supermarts ireda delta corp tata elxsi
# Category: news
# Headline: paytm shares jump 9 vijay shekhar sharma says goal build 100 billion company
# Category: news
# Headline: mc exclusive fo crackdown one weekly options contract per exchange min lot size rs 2030
# Category: news
# Headline: india added 47 crore jobs fy24 6 growth double previous year rbi data
# Category: news
# Headline: ge power india bags order ntpc
# Category: news
# Headline: gainers losers stocks moved july 8
# Category: news
# Headline: google maps exit ola offers inr 100 crore free credit ola maps
# Category: news
# Headline: wheel falls united airlines boeing moments takeoff la airport watch
# Category: news
# Headline: jefferies surprised indian markets resilience post election says midcaps face greatest correction risk
# Category: news
# Headline: earnings preview end downgrade cycle
# Category: news
# Headline: elon musk ’ tesla yet plug india government plans changes new ev policy tweaks may bene
# Category: news
# Headline: adani spend 9bn green hydrogen gujarat eye exports report
# Category: news
# Headline: sjvn share price target 2024 rs 1 lakh became rs 3 lakh 1 yr time buy psu stock gains
# Category: news
# Headline: bears flock hdfc bank counter loan deposit growth slows
# Category: news
# Headline: patel engg chairman rupen patel dies 57
# Category: news
# Headline: raymond share price jumps 18 3 days demerger plans buy multibagger stock
# Category: news
# Headline: tata curvv electric coupe suv teased ahead launch need know
# Category: news
# Headline: koo founder announces new consumer tech venture seeks engineering talent
# Category: news
# Headline: paramount skydance merge signaling end family reign hollywood rise new power
# Category: news
# Headline: gold price plummets us yields drop china stops bullion buying
# Category: news
# Headline: passengers impacted delayed flights ever shows data
# Category: news
# Headline: stocks buy sell rvnl rcf alembic — sumeet bagadia recommends five breakout stocks today
# Category: news
# Headline: air india welcomes first narrow body aircraft delhi
# Category: news
# Headline: indian game firms want distance fantasy sports
# Category: news
# Headline: premiumization mahindra suvs holds mirror luxury housing amit kumar sinha md mahindra lifespaces
# Category: news
# Headline: hyundai suv cheaper rs 2 lakh
# Category: news
# Headline: blackstone talks gobble majority stake haldirams ₹70000 cr deal report
# Category: news
# Headline: analyst call tracker tata motors emerges top bet auto sector rival maruti suzuki sees downgrades
# Category: news
# Headline: mc inside edge sudden swift jump fertiliser stocks three stocks limelight fo risky trend small caps
# Category: news
# Headline: gautam adani plans build ships flagship mundra port report
# Category: news
# Headline: stock market today bse sensex back 80100 nifty50 near 24350
# Category: news
# Headline: rvnl valued higher ircon rites jupiter wagons titagarh combined
# Category: news
# Headline: sbi keen sell 24 stake yes bank
# Category: news
# Headline: indian eyes modest growth apriljune qtr
# Category: news
# Headline: affle india shares 4 hit 52week high citi initiates coverage buy
# Category: news
# Headline: suzlon peer inox wind bags order wind turbine generators shares fly 6
# Category: news
# Headline: indias uday kotak got caught adani inquiry latest hindenburg twist
# Category: news
# Headline: lt expands semiconductor business ₹183 crore siliconch acquisition
# Category: news
# Headline: nifty bank closes lower strong support placed 52000 experts
# Category: news
# Headline: mgl pitti engineering concor senco gold godrej consumer stocks watch july 9
# Category: news
# Headline: govt reopens pli scheme white goods till october 12
# Category: news
# Headline: india added 25 times jobs fy24 highest since 198182 rbi data
# Category: news
# Headline: tea prices soar heatwaves floods slash output key producing regions
# Category: news
# Headline: mcx technical glitch commodity trading begins 10 one hour delay
# Category: news
# Headline: iphone success apple wants revive make india plans ipads airpod cases report
# Category: news
# Headline: blackrock buys 455 mn shares swan energy worth rs 304 cr via block deal
# Category: news
# Headline: stocks buy sell rvnl rcf alembic — sumeet bagadia recommends five breakout stocks today
# Category: news
# Headline: nuvama initiates coverage railway stock sees 21 upside
# Category: news
# Headline: oil prices plunge gaza peace talks hurricane beryl impact brent crude 8612bbl
# Category: news
# Headline: zerodha glitch man explains lost rs 10 lakh seeks help
# Category: news
# Headline: arnold schwarzenegger inspired mercedes electric car
# Category: news
# Headline: gold jumps ahead fed powell ’ testimony
# Category: news
# Headline: exclusive dezerv raises 32 mn premji invest others valuation 200 mn
# Category: news
# Headline: ducati hypermotard 698 mono launch price rs 165 lakh rve arrival later
# Category: news
# Headline: wall street today us stocks edge higher ahead key economic events chip shares rally
# Category: news
# Headline: skoda launch premium suv kodiaq india
# Category: news
# Headline: pc jeweller stock hits 10 upper circuit pnb approves onetime settlement dues
# Category: news
# Headline: ratan tatas company earns rs 38000 crore 5 days becomes biggest
# Category: news
# Headline: trade setup today top 15 things know opening bell
# Category: news
# Headline: equity fund inflows rise 17 rs 40608 crore june fresh high amfi data
# Category: news
# Headline: maruti suzuki shares surge 6 govt waives registration fee hybrid cars check details
# Category: news
# Headline: mc inside edge sudden swift jump fertiliser stocks three stocks limelight fo
# Category: news
# Headline: mc exclusive
# Category: news
# Headline: amid valuation concerns hdfc defence fund stops new sip registrations effective july 22
# Category: news
# Headline: inox wind shares gain nearly 7 securing 200mw order
# Category: news
# Headline: yes bank stake sale report factually incorrect got approval rbi bank clarifies
# Category: news
# Headline: stocks watch july 9 dixon tech swan energy bajaj finserv senco gold
# Category: news
# Headline: employment rate rises 6 provisionally fy24 32 fy23 rbi data
# Category: news
# Headline: emcure pharma ipo namita thaparbacked issue may debut 30 gains amid high investor interest
# Category: news
# Headline: irfc share price target 2024 railway stock tumbles scaling fresh high buy sell hold
# Category: news
# Headline: hyundai pressure tata mahindra 35 billion india ipo looms
# Category: news
# Headline: lt bags order construction 2 fleet support ships indian navy
# Category: news
# Headline: crude oil prices brent wti shed 025 subdued impact hurricane beryl
# Category: news
# Headline: 2024 mercedes eqa eqb electric suvs india launch price rs 66 lakh
# Category: news
# Headline: adani build ships mundra port gujarat likely focus green vessels longterm says report
# Category: news
# Headline: lt acquire semiconductor design firm siliconch
# Category: news
# Headline: bansal wire industries ipo allotment today stepbystep guide check status check gmp today
# Category: news
# Headline: apple may start ipad production india airpod charging cases jabil facility pune says report
# Category: news
# Headline: indian phd scholar says air india forgot load suitcase us flight bengaluru ‘ ’ 36 hours
# Category: news
# Headline: jupiter wagons shares plunge 3 despite qip launch find
# Category: news
# Headline: wealthtech startup dezerv raises 32 mn series b
# Category: news
# Headline: tata group airlines move step closer merger
# Category: news
# Headline: paytm like daughter met accident icu vijay shekhar sharma
# Category: news
# Headline: swiggys early investors dilute stakes ahead expected ipo report
# Category: news
# Headline: unsold cars worth rs 60000 crores lying dealers time high inventory
# Category: news
# Headline: nifty 50 likely rise short term bhel cdsl among top technical picks rupak de lkp securities
# Category: news
# Headline: trade spotlight trade sjvn apollo hospitals ircon coforge midhani others
# Category: news
# Headline: hft scan gujarat mineral development corporation ircon international focus
# Category: news
# Headline: rs 85 ipo gmp today 97 latest grey market premium check company name
# Category: news
# Headline: quant mutual fund investors withdraw rs 2800 crore amid sebi probe report
# Category: news
# Headline: accenture acquires excelmax technologies expand silicon design engineering capabilities newsroom
# Category: news
# Headline: ducati hypermotard 698 mono launch price rs 165 lakh rve arrival later
# Category: news
# Headline: wheel falls united airlines boeing moments takeoff la airport watch
# Category: news
# Headline: share market highlights 9 july 2024 sensex nifty trade firm maruti suzuki surges 6
# Category: news
# Headline: wipro settles noncompete lawsuits former execs cognizant pays 505k settlement
# Category: news
# Headline: crisishit paytm gets govt panels nod invest payments arm report
# Category: news
# Headline: freedom vs splendor bajaj autos new cng foray gets thumbs analysts
# Category: news
# Headline: sebi committee proposes stricter measures curb derivatives volume raises lot size ₹2030 lakh report
# Category: news
# Headline: tata motors reduces price harrier safari provide benefits 140000
# Category: news
# Headline: new thematic multicap mutual funds drive equity inflows another record
# Category: news
# Headline: xiaomi su7 electric car showcased india 10th anniversary celebration
# Category: news
# Headline: sbi sell entire 24 stake yes bank 4 years rescue report
# Category: news
# Headline: good news maruti suzuki cars offer double warranty kilometres run details
# Category: news
# Headline: mobile tariff hike affordable monthly yearly plans reliance jio airtel
# Category: news
# Headline: adani build ships mundra port gujarat likely focus green vessels longterm says report
# Category: news
# Headline: mahindra xuv700 ax7 price cut rs 22 lakh official price list
# Category: news
# Headline: nikhil kamaths ‘ sht marketing ’ jibe ather energy gets witty comeback bengaluru ceo
# Category: news
# Headline: mumbai delhi housing prices soar 48 five years unsold inventory declines
# Category: news
# Headline: zerodha glitch man explains lost rs 10 lakh seeks help
# Category: news
# Headline: microsoft ditches android apple iphones china citing security authentication issues
# Category: news
# Headline: tata motors group global wholesales 329847 q1 fy25
# Category: news
# Headline: mahanagar gas increases cng domestic png prices mumbai report check latest rates igl gujarat gas
# Category: news
# Headline: q1 results tcs dmart hcl tech ireda among companies declaring quarterly earnings week
# Category: news
# Headline: netizens poke holes ola founders indiaspecfic narrative inhouse map tool bears strong resemblance openstreetmaps
# Category: news
# Headline: bansal wire ipo allotment status gmp signals ahead share listing date
# Category: news
# Headline: motilal oswal takes bullish view ongc gail ahead earnings
# Category: news
# Headline: top power stock picks investec highlights nhpc inox wind among preference
# Category: news
# Headline: blackrock buys shares worth rs 304 crore swan energy
# Category: news
# Headline: stock buy anand rathi sees 20 upside multibagger psu hindustan copper shares recommends ‘ buy ’
# Category: news
# Headline: first tata curvv ev official teasers ahead launch
# Category: news
# Headline: sebi tweaks norms mutual fund investments listed securities sponsor
# Category: news
# Headline: cognizant pays 505087 settle noncomplete wipro lawsuit cfo jatin dalal
# Category: news
# Headline: hdfc mutual fund discontinue lumpsum subscription restrict systematic transactions defence fund
# Category: news
# Headline: maruti suzukis share price shoots govt scraps tax could save hybrid buyers ₹3 lakh
# Category: news
# Headline: fo trading sebi panel suggests rs 2030 lakh minimum lot size one weekly options contract per exchange
# Category: news
# Headline: tcs q1fy25 results pat may grow 8 yoy rs 11984 crore revenue uptick seen 48
# Category: news
# Headline: blackrock buys 455 mn shares swan energy worth rs 304 cr via block deal
# Category: news
# Headline: inflation impact sambar luxury chutney staple many lowerincome households bengaluru
# Category: news
# Headline: emcure pharmaceuticals share price makes strong debut stock opens 315 premium ₹132505 apiece nse
# Category: news
# Headline: mm bank stocks halt dstreets record run sensex sheds 150 points nifty 24400
# Category: news
# Headline: zomato ’ ad 16th janamdin gets shoutout paytm ceo vijay shekhar sharma
# Category: news
# Headline: amazon pay sees big opportunities indias small towns offline payments
# Category: news
# Headline: rvnl bags ₹20287 cr order south eastern railways
# Category: news
# Headline: bullish calls maruti ups hybrid tax break sends stock higher
# Category: news
# Headline: bansal wire industries ipo listing date today latest gmp experts see share listing price strong premium
# Category: news
# Headline: markets news july 9 2024 sp 500 nasdaq inch higher extend winning streaks
# Category: news
# Headline: delta corp share price slumps 4 weak q1 results net profit dives 68 yoy
# Category: news
# Headline: mutual fund sips hit new high rs 21260 crore june cross rs 1 lakh crore mark 2024
# Category: news
# Headline: buy sell apollo tyres union bank vaishali parekh recommends three stocks buy today — july 10
# Category: news
# Headline: massive rs 2 lakh price cut mahindra xuv700 short time details new pricing
# Category: news
# Headline: q1 result season begins 30 companies may report 100 growth profit
# Category: news
# Headline: rbi red flags lakhs accounts used fraud evergreening
# Category: news
# Headline: trade setup 10 july bank nifty hold crucial 52000 mark expiry day
# Category: news
# Headline: stocks watch reliance industries wipro ongc rvnl mahindra mahindra bansal wires emcure pharma
# Category: news
# Headline: fo frenzy equities turning stampede warns vijay kedia
# Category: news
# Headline: adani power unit sell electricity 20year deal reliance industries
# Category: news
# Headline: reliance jio introduces new true unlimited upgrade addon plans amid customer backlash tariff hikes
# Category: news
# Headline: latest rbi jobs data show bump employment
# Category: news
# Headline: samsung workers form union tn unit raise demands
# Category: news
# Headline: ongc invest rs 2 trillion meet net zero carbon emission target
# Category: news
# Headline: trade setup today top 15 things know opening bell
# Category: news
# Headline: stocks news delta corp paytm delhivery mankind pharma jsw steel
# Category: news
# Headline: union budget 2024 good time push disinvestment public banks says sbi report
# Category: news
# Headline: tcs q1 result preview key numbers deal pipelines5 key things watch majors junequarter earnings
# Category: news
# Headline: trade spotlight trade jbm auto ceat zomato sun pharma ipca labs others wednesday
# Category: news
# Headline: kia launches five new variants seltos sonet
# Category: news
# Headline: yatra online ordered speed covid19 related pending refunds worth ₹25 cr
# Category: news
# Headline: almm india ’ solar module manufacturing capacity touches 508 gw
# Category: news
# Headline: maruti suzuki extended warranty whats covered
# Category: news
# Headline: chandra shekhar ghosh hangs boots bandhan bank md ceo
# Category: news
# Headline: need know fii positions going trade july 10
# Category: news
# Headline: 20240709 lt wins significant order part construction two fleet support ships
# Category: news
# Headline: gold stays bid start powell testimony
# Category: news
# Headline: jerome powell says good data would strengthen case rate cuts federal reserve
# Category: news
# Headline: information received quant mutual fund investigation amfis ceo
# Category: news
# Headline: amazon prime day 2024 early deals discounts electronics gadgets home appliances
# Category: news
# Headline: raymond demerger last day buy stock qualify eligibility
# Category: news
# Headline: mumbaibased realty firm ashwin sheth group plans float ipo next 2 years raise ₹2000 ₹3000 crore
# Category: news
# Headline: gautam adani start shipbuilding mundra port amid global demand surge
# Category: news
# Headline: rvnl inks mou tatweer wins rs 187crore nagpur metro contract
# Category: news
# Headline: stock market crash sensex crashes 800 points smallcaps worst hit 5 factors brought bears
# Category: news
# Headline: stocks watch july 10 angel one emcure pharma mankind pharma mm
# Category: news
# Headline: bullish calls maruti ups hybrid tax break sends stock alltime high
# Category: news
# Headline: indias reserve bank says 40 million jobs created last year
# Category: news
# Headline: rvnl shares rally 10 mou order win another ₹1408 crore block seen
# Category: news
# Headline: tata harrier safari price cut rs 14 lakh variants new prices
# Category: news
# Headline: bse may benefit sebi proposal curb fo frenzy
# Category: news
# Headline: results play earnings growth moderate banks q1 stocks buy
# Category: news
# Headline: rajiv bajaj hero motocorp bajaj cng bike launch tiger zinda hain
# Category: news
# Headline: top stock recommendations sagar doshi nuvama suggests laurus labs balrampur chini hindalco today
# Category: news
# Headline: keralas airline air kerala take soon air kerala news air kerala flight travel
# Category: news
# Headline: tcs q1 preview june quarter likely softer margin may remain pressure
# Category: news
# Headline: adani ports shares inch winning bid run berth gujarat port
# Category: news
# Headline: namita thapars emcure pharma lists 31 premium nse
# Category: news
# Headline: gold holds positive ground ahead fed chair powell ’ second testimony
# Category: news
# Headline: q1 earnings preview flat 4 growth net profit expected nifty pack auto financials health
# Category: news
# Headline: stocks watch godrej consumer godrej industries bajaj finserv torrent power container corp jsw steel
# Category: news
# Headline: cesc share price stock surged 10 tuesday explained
# Category: news
# Headline: hdfc defence fund halt new sip registrations july 22
# Category: news
# Headline: nifty 50 sensex today expect indian stock market trade july 9
# Category: news
# Headline: many internal accounts could doorway evergreening rbi warns cfos
# Category: news
# Headline: mc exclusive
# Category: news
# Headline: snorting 20 billion dry powder india
# Category: news
# Headline: new toyota fortuner rival coming 2025
# Category: news
# Headline: bofa downgrades hdfc bank cuts target price 20 rally feblows
# Category: news
# Headline: trade spotlight trade jbm auto ceat zomato sun pharma ipca labs others
# Category: news
# Headline: people dont purchase highend luxurious cars suffer discomfort supreme court holds mercedes benz live law
# Category: news
# Headline: trading 32x risk correction greatest jefferies market view ahead budget 2024
# Category: news
# Headline: ipo gmp price today rs 258 latest grey market premium last date subscription alert
# Category: news
# Headline: paytm hot water bengaluru labour body looks allegations forced layoffs without pay report
# Category: news
# Headline: mazagon dock shares correct 10 record highs cochin shipyard grse decline
# Category: news
# Headline: sensex tumbles 1000 pts intraday stock markets falling today
# Category: news
# Headline: official employment data masks indias jobs problem say economists
# Category: news
# Headline: auto stocks shift gears maruti suzuki soars policy boost mm tata motors lag ‘ hybrid ’ musthave say analysts
# Category: news
# Headline: bansal wire ipo listing shares list 39 premium nse key things know
# Category: news
# Headline: sebi committee set evaluate fo expert panel recommendations volatility leverage
# Category: news
# Headline: gold price india rates july 10
# Category: news
# Headline: zomato ceo deepinder goyal wife grecia munoz celebrate delivery giant ’ 16th birthday gurgaon school kids
# Category: news
# Headline: rec pfc shares hit new record high add book profits
# Category: news
# Headline: telecom equipment manufacturing sales cross rs 50000 crore milestone pli scheme
# Category: news
# Headline: q1 result season begins 30 companies may report 100 growth profit
# Category: news
# Headline: asian paints hikes prices 071 across portfolio
# Category: news
# Headline: weekly picks tvs motor bhel motilal oswal suggests three stocks buy week
# Category: news
# Headline: angel one data breach investors data leaked brokerage comments reports
# Category: news
# Headline: new hyundai exter knight edition teased n line
# Category: news
# Headline: reliance jio introduces new ’ true unlimited upgrade ’ addon plans amid customer backlash tariff hikes
# Category: news
# Headline: amazon pay india bats fair mdr upi payments small merchants
# Category: news
# Headline: union budget 202425 likely go vocal higher local procurement
# Category: news
# Headline: npci likely fix 12 interchange credit line upi issue circular next week
# Category: news
# Headline: buyback alert kddl repurchase shares existing shareholders 12 premium
# Category: news
# Headline: rvnl inks mou ims consultancy technical advisory services nepal
# Category: news
# Headline: rvnl siemens bag order bengaluru metro advanced rail electrification
# Category: news
# Headline: trade spotlight trade nestle alkem labs hindustan copper bhel others tuesday
# Category: news
# Headline: ‘ take court ’ angry investor zerodha ceo nikhil kamath
# Category: news
# Headline: market trading guide dr reddys eicher motors among 6 top stock recommendations wednesday
# Category: news
# Headline: chandra shekhar ghosh hangs boots bandhan bank md ceo
# Category: news
# Headline: yes bank ’ 5 billion stake said attract lenders middle east japan
# Category: news
# Headline: microsoft quits sam altmans openai board ‘ longer necessary… ’
# Category: news
# Headline: top gainers losers today 10 july 2024 asian paints sbi life insurance company mahindra mahindra tata steel among active stocks check full list
# Category: news
# Headline: share market highlights sensex nifty50 retreat record highs amid weakness auto financial
# Category: news
# Headline: link hybrid car policy xuv 700 price cut clarifies mm
# Category: news
# Headline: 2024 byd atto 3 electric launch price 25 lakh 3 variants 521 kms range
# Category: news
# Headline: ev race hybrid vehicles getting faster lane
# Category: news
# Headline: kotak warns crushing lasting impact possible sebi guardrails derivatives trading
# Category: news
# Headline: budget 2024 may propel key element modi govts panchamrit goals
# Category: news
# Headline: khadi sales rise 93 rs 6496 crore fy24
# Category: news
# Headline: grecia munoz breaks instagram silence months marrying zomato ceo deepinder goyal see post
# Category: news
# Headline: hyundai exter goes black knight edition celebrates 1st anniversary 93k sales
# Category: news
# Headline: adani power shares jump energy agreement reliance
# Category: news
# Headline: 2024 tvs apache rtr 160 race edition launched rs 129 l sportier design
# Category: news
# Headline: bajaj freedom 125 — cng tech work
# Category: news
# Headline: icici bank sbi among nomura ’ 4 preferred banking stocks ahead q1 results
# Category: news
# Headline: delta corps share price plummets q1 net profit takes huge hit
# Category: news
# Headline: accenture acquires cientra expand silicon design capabilities newsroom
# Category: news
# Headline: angel one assures data integrity denies new leak customer data
# Category: news
# Headline: bel zooms 80 ytd investors chase psu defence stock ’ stellar performance
# Category: news
# Headline: zepto selling dhaniya ₹140 gurgaon social media united outrage
# Category: news
# Headline: nifty auto plummets nearly 3 mm tata motors fall sharply maruti suzuki hits new record high
# Category: news
# Headline: equity fund inflows jump 17 june ₹40000 cr shows amfi data
# Category: news
# Headline: export duty parboiled rice may fixed 100tonne
# Category: news
# Headline: hdfc bank share declines bofa downgrades stock ‘ neutral ’ cuts target price
# Category: news
# Headline: technical view
# Category: news
# Headline: rbi cautions banks ‘ lakhs accounts ’ used fraudulent transactions evergreening
# Category: news
# Headline: wealthy indians buy property get residency 10 countries check much costs
# Category: news
# Headline: powell speech see current fed policy restrictive
# Category: news
# Headline: tata curvv new teasers show offroad prowess thar desert himalayas
# Category: news
# Headline: supreme court orders mercedes refund ₹36 lakh defective car bar bench
# Category: news
# Headline: tata elxsi q1 results net profit falls 3 yoy rs 184 crore
# Category: news
# Headline: canara bank plans raise rs 10k cr infrastructure bonds fy25
# Category: news
# Headline: top 5 index sip mutual funds 5 years 1 fund turned rs 25000 monthly sip rs 31 lakh bel trent hal main stocks
# Category: news
# Headline: nhpc share price target till budget check makeorbreak level psu stock
# Category: news
# Headline: raymond committed creating sustained shareholder value across businesses gautam singhania
# Category: news
# Headline: ongc invest ₹2 lakh cr meet net zero emission target
# Category: news
# Headline: cognizant settles wipro lawsuit former chief financial officer jatin dalal
# Category: news
# Headline: mhcv bus sales shift q1 top 4 players register 72 growth
# Category: news
# Headline: brokerages bullish maruti governments tax waiver hybrid vehicles
# Category: news
# Headline: bansal wire share price falls marginally post robust listing hold exit
# Category: news
# Headline: hdfc bank share declines bofa downgrades stock ‘ neutral ’ cuts target price
# Category: news
# Headline: stock market today bse sensex surges 600 points move 80500 nifty50 24500 bulls
# Category: news
# Headline: ireda share price hits lifetime high ahead q1 results today buy psu stock jumps 25 three days
# Category: news
# Headline: stocks watch today tcs adani wilmar infosys vodafone idea
# Category: news
# Headline: tcs q1 fy25 earnings surprise prompts major brokerages target prices
# Category: news
# Headline: cpi inflation continues close 5 early talk rate cut shaktikanta das
# Category: news
# Headline: quant mutual funds cfo resigns amid sebis frontrunning probe
# Category: news
# Headline: rbi allows residents open foreign currency bank accounts within indian jurisdiction
# Category: news
# Headline: stock market today trade setup nifty 50 q1 results today five stocks buy sell friday — july 12
# Category: news
# Headline: railtel shares jump 11 hit fresh 52 week high multibaggers irfc ircon join party new peaks
# Category: news
# Headline: 140 million hdfc bank axis customers may face service interruption
# Category: news
# Headline: jio financial services jumps receiving rbi nod go nbfc core investment company
# Category: news
# Headline: zomato shares hit alltime high brokerage raises price target
# Category: news
# Headline: govt ’ hybrid vehicle tax waiver cars conditions apply
# Category: news
# Headline: stocks buy sell ponni sugars mazda — sumeet bagadia recommends five breakout stocks today
# Category: news
# Headline: sp 500 nasdaq tumble us cpi inflation moderates gift nifty
# Category: news
# Headline: zee entertainment announces dates board meet consider fund raise stock surges 6
# Category: news
# Headline: data centers push indias power generation needs 280 billion investment expected
# Category: news
# Headline: reliance jio could list 112bn valuation 15 upside ril jefferies
# Category: news
# Headline: gold price falls india check 22 carat rate city july 11
# Category: news
# Headline: oil extends gains us inflation data pushes wall street lift fed rate cut bets brent stays 85bbl
# Category: news
# Headline: hcl tech q1 results preview pat may grow 6 yoy rs 3745 crore revenue uptick seen 65
# Category: news
# Headline: anand rathi wealth q1 result
# Category: news
# Headline: sachin tendulkarbacked small cap stock jumps 4 bagging siemens order
# Category: news
# Headline: ongc oil india selan fire heres fueled 13 rally today
# Category: news
# Headline: acer ties indkal technologies enter indian phone market
# Category: news
# Headline: gold surges 2400 mark us inflation data boosts ratecut expectations silver 27
# Category: news
# Headline: mahindra mahindra stock declines second consecutive day right time buy check target b
# Category: news
# Headline: shortage indiamade solar modules hits projects dcr mandate
# Category: news
# Headline: adani wilmar diversifies portfolio majority stake acquisition speciality chemicals company
# Category: news
# Headline: could sebis new proposal unintentionally favour bse nse
# Category: news
# Headline: byd introduces affordable atto 3 variant smaller battery pack
# Category: news
# Headline: namita thapars emotional post emcure ipo listing ‘ mirza ghalib sums feelings ’
# Category: news
# Headline: bajaj freedom cng tank filling experience public reactions caught cam
# Category: news
# Headline: brookfield buy controlling stake leap green 550 million
# Category: news
# Headline: sjvn share price lic ups stake retail shareholding rises 12 lakh
# Category: news
# Headline: multibagger small cap railway stock wins ₹432 cr order railways
# Category: news
# Headline: iphone android users beware fake india post messages
# Category: news
# Headline: adani realty tops hurun real estate ranking valuable unlisted company
# Category: news
# Headline: hindustan zinc inks deal acquire 180mw renewable energy serentica
# Category: news
# Headline: four public issues hit dalal street july 12 check details
# Category: news
# Headline: nearly 70 tcs employees return office variable pay linked attendance
# Category: news
# Headline: budget 2024 remedial steps fire local manufacturing
# Category: news
# Headline: demat account additions cross 40 lakh fourth time june nse active clients 3
# Category: news
# Headline: first abu dhabi bank denies interest acquiring stake yes bank report
# Category: news
# Headline: compact suv sales june 2024 creta g vitara seltos hyryder elevate taigun kushaq
# Category: news
# Headline: hyundai india celebrates exters first anniversary launch exter knight
# Category: news
# Headline: abb india shares pressure ubs downgrades stock
# Category: news
# Headline: dstreets cooling earnings momentum set challenge stock rally
# Category: news
# Headline: heres nvidias chips may disrupt big fat indian weddings
# Category: news
# Headline: decoding airtel ’ new xstream fiber bundles seeking value live tv ott
# Category: news
# Headline: yes bank shares jump 7 outlook upgrade moodys
# Category: news
# Headline: mutual funds fiis cut shareholding bharat electronics
# Category: news
# Headline: shipping corporation india stock jumps another 165 40 3 sessions heres triggered rally
# Category: news
# Headline: hpl electric surges 15 bagging rs 2000 crore order
# Category: news
# Headline: vi shareholders okay rs 2458 cr preferential issue nokia ericsson
# Category: news
# Headline: mahindra thar 5door spied three new shades debut august 15
# Category: news
# Headline: car retail sales june 2024 maruti hyundai tata mahindra toyota kia honda citroen jeep byd
# Category: news
# Headline: 277 return 1 year multibagger psu stock focus today heres
# Category: news
# Headline: explainer vijay kedia stock adani power among 1000 scrips knocked acceptable nse coll
# Category: news
# Headline: tata elxsi shares red net profit falls kotak maintains sell
# Category: news
# Headline: bsnl presence crucial keep check private telcos ’ monopolistic pricing bms pm modi
# Category: news
# Headline: analyst suggests buying multibagger defence psu stock budget 2024
# Category: news
# Headline: raymond shares hit upper circuit trading exdate lifestyle arm demerger
# Category: news
# Headline: top 5 multicap mutual funds highest sip returns 5 years rs 20000 monthly sip no1 fund gro
# Category: news
# Headline: ambuja double upgrade nomura sees another 18 upside adani group cement stock
# Category: news
# Headline: neuralink implant second brain chip next week elon musk says ‘ give people super powers… ’
# Category: news
# Headline: dneg group completes acquisition prime focus technologies
# Category: news
# Headline: two stocks witnessed highest fii activity wednesday
# Category: news
# Headline: tcs shares surge 6 strong q1 show lifting dstreet fresh record highs
# Category: news
# Headline: rbi governor hints interest rates may stay higher longer
# Category: news
# Headline: trade spotlight trade tata motors voltas bpcl bhel eil itc others friday
# Category: news
# Headline: jio financial services gets rbi green light become core investment company
# Category: news
# Headline: zerodhas prompt action hailed ‘ overtrader ’ loses ₹10 lakh due bug gets refund 48 hours went wrong
# Category: news
# Headline: rcf stock zooms 10 hit record high rs 515 crorder win
# Category: news
# Headline: adani wilmar buy 67 stake omkar chemicals aims expand footprint
# Category: news
# Headline: india outshines china 36 real estate companies valued billion dollars
# Category: news
# Headline: yes bank shares climb 7 moodys outlook upgrade takes note healthy performance
# Category: news
# Headline: vodafone idea gets shareholders nod 2458 crore preferential issue nokia ericsson
# Category: news
# Headline: hcl tech q1 results cons pat jumps 20 yoy rs 4257 crore beats estimates
# Category: news
# Headline: nifty soars 5 strong tcs q1 earnings fed rate cut hopes nears alltime high
# Category: news
# Headline: india ’ retail inflation rises 4month high 508 june
# Category: news
# Headline: hdfc bank jpmorgan chase top 25 global banks mcap hits 411 trn q1
# Category: news
# Headline: traders diary buy sell hold strategy tcs infosys tata steel gcpl bhel voltas dozen oth
# Category: news
# Headline: ril q1 results fy 202425 date time announced ambaniled reliance industries quarterly earnings schedule
# Category: news
# Headline: ireda gains 7 crosses rs 300 mark first time investment strategy
# Category: news
# Headline: us cpi cools fed chair hints rate cuts investors strategy
# Category: news
# Headline: trade setup 12 july nifty50 extends consolidation close 24400 reaffirms bullish trend
# Category: news
# Headline: reduce tcs target rs 3950 emkay global financial
# Category: news
# Headline: quant mutual fund clarifies cfo resignation happened sebi probe amid media reports
# Category: news
# Headline: ola ceo calls 70hour work week doctor warns premature death risk
# Category: news
# Headline: adani wilmar acquires 67 stake omkar chemicals
# Category: news
# Headline: rbi allows resident indians open dollar accounts gift city means
# Category: news
# Headline: jio financial services gets rbi nod become core investment company
# Category: news
# Headline: ups sops hybrid vehicles irk ev companies add industrys june sob story
# Category: news
# Headline: mahindra sales breakup june 2024 – scorpio xuv700 bolero thar xuv400 ev
# Category: news
# Headline: ganesh green bharat share price makes bumper debut stock opens 90 premium ₹361 apiece nse sme
# Category: news
# Headline: tata power invests rs 4200 crore network expansion upgrade odisha
# Category: news
# Headline: inox wind stock jumps 10 climb new peak triples investors money year
# Category: news
# Headline: pfc stock gains 5th straight day govt appoints sandeep kumar director finance
# Category: news
# Headline: firm development shipping corp denies reports oil tanker jv shares race record high
# Category: news
# Headline: gold rises us cpi shows cooling inflation
# Category: news
# Headline: variable pay brought 70 tcs staff back office
# Category: news
# Headline: invesco lowers valuations ipobound swiggy pine labs
# Category: news
# Headline: dlf chairman rajiv singh leads wealth rankings 2024 grohehurun report indias real estate titans
# Category: news
# Headline: railway stock surges 5 hits upper circuit winning ₹432 cr order
# Category: news
# Headline: indias second electrolyser manufacturing auction oversubscribed bids nearly double cap
# Category: news
# Headline: modi govt departs privatisation plans might overhaul staterun firms
# Category: news
# Headline: carmakers resort discount offers price cuts revive volumes
# Category: news
# Headline: kia exchange car simple quick online evaluation tool
# Category: news
# Headline: union budget 202425 likely relax compliance customs rules
# Category: news
# Headline: bel bags export orders worth ₹230 cr thales reliance defence systems
# Category: news
# Headline: tata punch ice cng facelift spied exteriors interiors new details
# Category: news
# Headline: waaree subsidary indosolar commences 130 gw solar module facility
# Category: news
# Headline: first abu dhabi bank says evaluating offer stake yes bank
# Category: news
# Headline: zomato ordered pay rs 60000 karnataka woman delivering momos worth rs 13325
# Category: news
# Headline: tcs stocks power nifty fresh alltime high
# Category: news
# Headline: indias industrial production beats estimates growth seen 59 yoy may
# Category: news
# Headline: hcl technologies q1 results profit jumps nearly 7 fy25 guidance maintained
# Category: news
# Headline: exclusive india antitrust probe finds apple abused position apps market
# Category: news
# Headline: tcs share price likely open green q1 results india biz revenue strengthens show analysts
# Category: news
# Headline: stocks watch july 12 tcs mm affle nazara tech abfrl anand rathi
# Category: news
# Headline: ireda stock surges 6 fresh record high ahead q1 results 364 year
# Category: news
# Headline: gold extends correction factorygate inflation release surprises upside
# Category: news
# Headline: reliance industries announce q1 results july 19 heres expect
# Category: news
# Headline: sati poly plast ipo day 1 check subscription status gmp key dates need know
# Category: news
# Headline: rbis new circular foreign currency accounts means indians
# Category: news
# Headline: exclusive indias modi delays privatisation plans
# Category: news
# Headline: reliance jio ipo likely 2025 112billion valuation says jefferies
# Category: news
# Headline: nse latest circular adani power yes bank suzlon 1010 stocks removed list details
# Category: news
# Headline: brokerages maintain optimism mm despite xuv 700 price cut
# Category: news
# Headline: ireda q1 results net profit ₹383 crore revenue 32 yoy loan sanction grows manifold ₹9210 crore
# Category: news
# Headline: ola ceo endorses 70hour work week top neurologist warns severe illness
# Category: news
# Headline: buy tcs target rs 4660 motilal oswal
# Category: news
# Headline: stocks news tcs hcl tech anand rathi wealth prestige estates ril
# Category: news
# Headline: 415 returns 1 year multibagger railway psu shines dstreet big orders stock 60 1 month
# Category: news
# Headline: users report losing lakhs due glitch zerodha company responds
# Category: news
# Headline: 20 mfs added 10 stocks june witness surge upto 70 fy25
# Category: news
# Headline: facelifted tata punch spied likely get bigger touchscreen unit
# Category: news
# Headline: bharat electronics receives export order worth rs 230 crore
# Category: news
# Headline: us dollar slumps inflation eases stocks gold silver rally
# Category: news
# Headline: tcs 70 employees return office attendancelinked variable pay policy report
# Category: news
# Headline: japan ’ softbank exits paytm sells remaining 14 percent stake
# Category: news
# Headline: reliance q1 results india wpi china gdp week ahead
# Category: news
# Headline: dmart q1 results pat grows 175 yoy rs 774 crore revenue 19
# Category: news
# Headline: tata curvv launch august 7 heres upcoming coupe suv
# Category: news
# Headline: ireda share price experts see big upside strong q1 results 2024 buy sell
# Category: news
# Headline: quant mutual funds aum time high rs 94000 crore navs schemes hit record levels
# Category: news
# Headline: gold price nears rs 74000 india check 24 carat rates city july 13
# Category: news
# Headline: retail prices june soar 508 cooling lowest year
# Category: news
# Headline: top stories
# Category: news
# Headline: rvnl shipping corporation among 10 stocks rally 10 week top gainers
# Category: news
# Headline: buy sell sumeet bagadia recommends three stocks buy monday — july 15
# Category: news
# Headline: sahaj solar ipo gmp review subscription status listing date details may like know nse sme ipo
# Category: news
# Headline: ola ceo calls 70hour work week doctor warns health risks ‘ even premature death ’
# Category: news
# Headline: india worlds secondlargest economy 2031 rbi dg patra
# Category: news
# Headline: indian govt soon launch agrisure fund support agritech startups agripreneurs
# Category: news
# Headline: banking system update banking services including upi transfer remain closed 13 hours ju
# Category: news
# Headline: bajaj explains freedom cng tank 2 kgs give higher range
# Category: news
# Headline: indias forex reserves hit alltime high 65716 bn
# Category: news
# Headline: amfi suggestions union budget help mutual fund investors
# Category: news
# Headline: top 5 strong hybrid cars india road prices uttar pradesh new delhi
# Category: news
# ...
# Category: news
# Headline: 600 dividend stock record date announced q1 quarterly results fy25 – amount payment date
# Category: news
# Headline: ms dhoni renew power existing investors back ev ridehailing company blusmart 24 million preseries b funding
# Category: news
# Headline: trade setup 16 july bank nifty break sevenday consolidation
# Category: news
# Headline: hero motocorp nestle ultratech cement ntpc axis securities lists top stock picks union budget 2024
# Category: news
# Headline: rbi issues new circular says lenders must hear loan defaulters declaring accounts fraud
# Category: news
# Headline: gold silver price today july 15 2024 precious metals witness dip mcx
# Category: news
# Headline: zee entertainment gets shareholders nod raise upto rs 2000 crore via issue securities
# Category: news
# Headline: reduce hcl technologies target rs 1455 icici securities
# Category: news
# Headline: zomato mcap reaches rs 2 trn delivers deepinder goyal billionaire tag
# Category: news
# Headline: camlin ’ subhash dandekar passes away 81
# Category: news
# Headline: big movers dstreet investors railtel axis bank hcl tech
# Category: news
# Headline: macobs technologies ipo opens today check timeline price band key details
# Category: news
# Headline: kataria industries ipo opens today need know subscribing issue
# Category: news
# Headline: amazon prime day sale 2024 iphone 13 ₹47999 iqoo neo 9 pro ₹29999 top deals know
# Category: news
# Headline: us backtoschool spending remain muted 2024 deloitte says reuters
# Category: news
# Headline: nlc india bags odisha coal mine 138 billion tonnes capacity
# Category: news
# Headline: gold rises powell hints cuts 2 inflation goal
# Category: news
# Headline: varun beverages set production units pepsico zimbabwe zambia
# Category: news
# Headline: stocks buy sell hbl power birla cable — sumeet bagadia recommends five breakout stocks today
# Category: news
# Headline: oil prices ease demand concerns china reuters
# Category: news
# Headline: tcs hr boss linking variable pay work office punish employees
# Category: news
# Headline: samsung hilarious response apple opening first store malaysia ’
# Category: news
# Headline: among students manmohan singh least likely become pm amartya sen
# Category: news
# Headline: stock market today need know going trade july 16
# Category: news
# Headline: sjvn invites bids 12 gw istsconnected windsolar hybrid projects
# Category: news
# Headline: coal india shares get first price target ₹600 strong balance sheet dividend yield
# Category: news
# Headline: alphabet said talks buy cybersecurity startup wiz
# Category: news
# Headline: govt unlikely launch second semiconductor subsidy scheme year
# Category: news
# Headline: budget 2024 allocation gold 1020 cash buy dips smallcase managers reveal portfolio strategy budget
# Category: news
# Headline: 6 commodities stocks hit 52week highs rallied 40 month
# Category: news
# Headline: liquor home delivery swiggy zomato bigbasket restart covid19 lockdown days says report
# Category: news
# Headline: wall street today us stocks gain donald trump survives assassination attempt
# Category: news
# Headline: quant mfs sandeep tandon continue efforts create wealth investors
# Category: news
# Headline: bajaj auto shares green ahead q1 results heres expect
# Category: news
# Headline: loan default nclt declares gvk power infra bankrupt
# Category: news
# Headline: ireda share price dips 5 philip capital slaps sell tag opportunity bottom fishing
# Category: news
# Headline: lt tata tech among 7 stocks bet ahead union budget
# Category: news
# Headline: jio financial services q1 results live profit rise 335467 yoy
# Category: news
# Headline: nclt admits bcci ’ plea seeking insolvency proceedings byju ’
# Category: news
# Headline: muharram public holiday kerala tomorrow onmanorama muharram 2024 kerala
# Category: news
# Headline: vodafone idea shares jump nearly 6 sc agrees consider plea agr dues
# Category: news
# Headline: india ’ sector ramp hiring amid rising demand services
# Category: news
# Headline: gold sticks intraday gains bulls seem noncommitted amid riskonusd uptick
# Category: news
# Headline: ao smith buys huls pureit business india ₹601 crore
# Category: news
# Headline: mtnl interest obligations bonds honoured government sources
# Category: news
# Headline: iocs green hydrogen project sees sparse bids amidst industry concerns report
# Category: news
# Headline: zomatos mcap surges ₹2 lakh cr valuable tech mahindra tata consumer
# Category: news
# Headline: sembcorp industries sets ball rolling rs 36000 crore tn project
# Category: news
# Headline: bajaj auto q1 results cons pat jumps 18 yoy rs 1942 crore revenue rises 16
# Category: news
# Headline: hindustan unilever shares gain sale pureit business
# Category: news
# Headline: byjus crisis nclt admits bccis petition seeking insolvency proceedings cricketing body aims recover ₹158 crore
# Category: news
# Headline: job alert elon mask announces tesla xai looking hire networking engineers technicians
# Category: news
# Headline: budget 24 trading strategy three stocks perfect pitch trading budget day
# Category: news
# Headline: jio financial q1 results profit stays flat lower interest income
# Category: news
# Headline: hdfc life q1 results net profit rises 15 yoy rs 477 crore
# Category: news
# Headline: bill gatesbacked startup makes butter air claims tastes really good like real thing
# Category: news
# Headline: swiggy zomato hike platform fees online food delivery cost
# Category: news
# Headline: tata motors shares shot sharply tuesday
# Category: news
# Headline: sbi amrit kalash fd sbi fd offers highest interest rate know return values rs 5 lakh rs 10 lakh
# Category: news
# Headline: exclusive tata curvv ev unofficial bookings open
# Category: news
# Headline: tata steel q1 pat seen 377 yoy rs 870 cr prabhudas lilladher
# Category: news
# Headline: muharram bank holiday july 2024 banks states closed wednesday july 17
# Category: news
# Headline: dolly khanna portfolio multibagger stock chennai petroleum corporation hits record high logging 14 intraday rally
# Category: news
# Headline: gold rate today falls india check 22 carat price city july 15
# Category: news
# Headline: spicejet shares 8 percent anticipation muchdelayed financial results
# Category: news
# Headline: infosys q1 earnings preview revenue margin may return growth net profit set fall
# Category: news
# Headline: brokerages impressed hdfc amcs q1 show maintain buy
# Category: news
# Headline: big movers dstreet investors aurobindo pharma tanla platforms idbi bank
# Category: news
# Headline: mahindra thar 5door wheels 3door model aftermarket fitment launch
# Category: news
# Headline: gujarati family takes 73yearold car road trip ahmedabad london watch
# Category: news
# Headline: amazon prime day deals revealed big discount iphone 13 oneplus nord ce 4 poco m6
# Category: news
# Headline: ‘ godman ’ builds temple 16k feet uttarakhand glacier probe
# Category: news
# Headline: bajaj auto asian paints vbl top picks jigar patel anand rathi
# Category: news
# Headline: law tribunal admits bccis plea seeking insolvency process byjus
# Category: news
# Headline: bank holiday july 16 banks closed today harela check details
# Category: news
# Headline: bajaj auto q1 results cons pat jumps 18 yoy rs 1942 crore revenue rises 16
# Category: news
# Headline: elon musk claims x recorded ‘ alltime high ’ 417 billion user seconds globally platform july 15
# Category: news
# Headline: vedanta shares — lies ahead anil agarwals firm post ₹7000 crore qip
# Category: news
# Headline: sahaj solar ipo allotment likely fixed today latest gmp steps check allotment status
# Category: news
# Headline: swiggy zomato may start alcohol delivery states report
# Category: news
# Headline: cesc subsidiary purvah green supply maintain wind turbines suzlon energy
# Category: news
# Headline: heres rvnl shares falling trade today details
# Category: news
# Headline: icici sec upbeat defence stocks picks private players psus
# Category: news
# Headline: ethereum etf launch date confirmed sec greenlights trading july 23
# Category: news
# Headline: byju ’ valued 22 billion faces insolvency proceedings
# Category: news
# Headline: gold silver prices today 16072024 check latest rates city
# Category: news
# Headline: kerala likely launch online alcohol delivery via swiggy zomato onmanorama news
# Category: news
# Headline: paytm gets warning sebi old transactions banking unit
# Category: news
# Headline: wednesday bank holiday banks remain closed wednesday know rbi given holiday banks
# Category: news
# Headline: shocking twist hybrid car price drop union govt vs state govt
# Category: news
# Headline: gold xauusd ready print new alltime high latest sentiment analysis
# Category: news
# Headline: garden reach shipbuilders shares jump 3 bagging ₹840 cr order
# Category: news
# Headline: buy varun beverages target rs 1900 motilal oswal
# Category: news
# Headline: indian stock market 7 key things changed market overnight gift nifty dow jones record close oil prices
# Category: news
# Headline: kia ev6 recalled india affecting 1138 units reason ioniq 5
# Category: news
# Headline: despite filing itr successfully tax refund may credited bank account due issue
# Category: news
# Headline: adani looks add insolvent jaypee group assets arsenal amid war cement market share report
# Category: news
# Headline: india ’ sector ramp hiring amid rising demand services
# Category: news
# Headline: angel one stock gains profit revenue grows q1fy25
# Category: news
# Headline: rs 18 lakh crore boom defence stocks live budget hype
# Category: news
# Headline: camlin founder subhash dandekar dies
# Category: news
# Headline: sebi invites comments proposal new asset class bridging mutual funds pms
# Category: news
# Headline: fame 3 scheme final stages unlikely budget says heavy industries minister
# Category: news
# Headline: lt finance q1 results net profit rises 29 ₹686 crore
# Category: news
# Headline: budget 2024 ashok leyland siemens ultratech cement ncc among top 13 budget picks anand rathi
# Category: news
# Headline: tata curvv curvv ev debut date
# Category: news
# Headline: gold xauusd ready print new alltime high latest sentiment analysis
# Category: news
# Headline: staying quality pays long term wealth creation 5 midcap stocks different sectors potent
# Category: news
# Headline: several states including delhi karnataka tamil nadu may get liquor home delivery report
# Category: news
# Headline: bharti airtel foundation announces ₹100 crore scholarship tech students
# Category: news
# Headline: check sahaj solar ipo allotment status
# Category: news
# Headline: wall street today us stocks edge higher strong retail sales data robust earnings
# Category: news
# Headline: caps incentive electric cars revised notification deepens suspense hybrids
# Category: news
# Headline: tcs hr chief milind lakkad says linking variable pay bonus punish staff aimed boost ‘ return office ’
# Category: news
# Headline: union budget 2024 overseas credit card spending ₹7 lakh may taxed 20
# Category: news
# Headline: sectoral thematic funds catching investor fancy
# Category: news
# Headline: swiggy zomato might soon deliver alcohol states report
# Category: news
# Headline: ola electric ipo pricing likely 25 lower private valuation 54 billion sources
# Category: news
# Headline: imf raises indias gdp forecast 7 202425
# Category: news
# Headline: subhash dandekar founder camlin
# Category: news
# Headline: bank baroda bank maharashtra launch special fixed deposit schemes details
# Category: news
# Headline: breaking gold hits record high rate cut hopes surge xauusd breaches 2450
# Category: news
# Headline: stocks buy kec international tcs among top four picks smc global week eyes 1418 upside tp
# Category: news
# Headline: swiggy zomato might soon deliver alcohol states report
# Category: news
# Headline: stock market holiday indian stock market shut tomorrow
# Category: news
# Headline: chennai petroleum shares soar 14 stock approaches record date ₹55 dividend
# Category: news
# Headline: hcltech ceo vijayakumar said linking variable pay office attendance
# Category: news
# Headline: infosys shares cross rs 1731 level scale fresh 52week high analysts await q1 results due thursday
# Category: news
# Headline: garden reach shipbuilders bags ₹840 crore order national centre polar ocean research
# Category: news
# Headline: zomato makes new high 20 fee hike
# Category: news
# Headline: gainers losers stocks moved july 16
# Category: news
# Headline: exclusive crisis hit byju ’ locked 100 tuition centres unpaid rent
# Category: news
# Headline: buy varun beverages target rs 1900 motilal oswal
# Category: news
# Headline: ex rollsroyce head designer stabbed death 3 million germany mansion
# Category: news
# Headline: exbillionaire loses control byju ’ blow indias tech ambitions
# Category: news
# Headline: us market dow jones gains 740 points russell 2000 smallcap index rise rate cut bets
# Category: news
# Headline: imf raises india ’ fy25 growth forecast upward 7
# Category: news
# Headline: sebi mulls new asset class fill gap mutual funds pms
# Category: news
# Headline: breaking royal enfield guerrilla 450 launched rs 239000
# Category: news
# Headline: tata curvv suv debut 19th july – break creta ’ dominance
# Category: news
# Headline: indian banks special plans offering higher deposit rates
# Category: news
# Headline: q1 results today asian paints ltimindtree hathway cable datacom among 22 companies announce earnings july 17
# Category: news
# Headline: gold retreats alltime high amid profittaking potential downside seems limited
# Category: news
# Headline: zee board approves raising 239 mn 10yr foreign currency convertible bonds
# Category: news
# Headline: tata power sets ₹20000 crore investment target fy25 drive renewable energy expansion
# Category: news
# Headline: hyundai copies tata motors success mantra
# Category: news
# Headline: gold prices reach alltime high hyderabad
# Category: news
# Headline: hdfc life new competitor mutual fund industry
# Category: news
# Headline: indian aviation reports bestever first half 2024 indigo tata group airlines fly high spicejet biggest loser
# Category: news
# Headline: fraud tag loans hearing borrowers rbi banks
# Category: news
# Headline: jupiter wagons eyes 20fold jump exports ₹2000 crore fy26end
# Category: news
# Headline: bajaj auto shares green net profit jumps 19 ₹1988 cr
# Category: news
# Headline: psu stock planning buy ireda shares know brokerages views renewable energy stock
# Category: news
# Headline: hindustan aeronautics highaltitude orbit
# Category: news
# Headline: 6 energy stocks hit fresh 52week highs rallied 30 month
# Category: news
# Headline: dairy dreams milky mist eyes ipo rs 20000 crore valuation months westbridge talks fall
# Category: news
# Headline: fiis diis collectively buy 666 per cent stake multibagger airline company stock rs 60 jumped 985 per cent post turnaround net profit q4fy24
# Category: news
# Headline: swiggy investor keeps valuation unchanged ahead ipo zomato retains rich tag
# Category: news
# Headline: tech view nifty forms another doji candle ’ trade thursday
# Category: news
# Headline: modern bold muscular škoda auto india shares design glimpse allnew compact suv
# Category: news
# Headline: fo trading sebi discuss ways tighten screws retail speculation
# Category: news
# Headline: adani enterprises buy 775 coredgeio parent ₹20000 per share
# Category: news
# Headline: nselisted media stock hits 7year high net profit rises 49 q1fy25 ₹7 dividend declared buy sell
# Category: news
# Headline: multibagger stock rs 500 rs 1 lakh investment grows rs 3 lakh 1 yr q1 fy25 pat zooms 42
# Category: news
# Headline: watch deepinder goyal splits comedian roasts zomato ’ platform fee rain surge
# Category: news
# Headline: nclt holds gvk power infra bankrupt admits insolvency petition icici bank bar bench
# Category: news
# Headline: pace hero acme jsw win seci ’ 12 gw solar plus storage auction
# Category: news
# Headline: four unexplored indian basins may hold oil permian
# Category: news
# Headline: irdai imposes rs 2 crore penalty bajaj finance violating regulations
# Category: news
# Headline: camlin founder subhash dandekar passes away 86
# Category: news
# Headline: exclusive crisishit byju ’ locked 100 tuition centres unpaid rent
# Category: news
# Headline: stock radar jio financial angel one unichem labs hul vedanta focus tuesday
# Category: news

# %%
from nltk.corpus import wordnet as wn
wn.synsets('motorcar')
#[Synset('car.n.01')]
# Out:
# [Synset('car.n.01')]

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
for i in wn.synsets('stocks'):
    print(wn.synset(i).lemma_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in wn.synsets('stocks'):
# ----> 2     print(wn.synset(i).lemma_names())
#
# File ~\Documents\nlp\env\Lib\site-packages\nltk\corpus\reader\wordnet.py:1493, in WordNetCorpusReader.synset(self, name)
#    1491 def synset(self, name):
#    1492     # split name into lemma, part of speech and synset number
# -> 1493     lemma, pos, synset_index_str = name.lower().rsplit(".", 2)
#    1494     synset_index = int(synset_index_str) - 1
#    1496     # get the offset for this synset
#
# AttributeError: 'Synset' object has no attribute 'lower'

# %%
wn.synsets('shares')
# Out:
# [Synset('share.n.01'),
#  Synset('share.n.02'),
#  Synset('parcel.n.02'),
#  Synset('contribution.n.01'),
#  Synset('plowshare.n.01'),
#  Synset('share.v.01'),
#  Synset('share.v.02'),
#  Synset('partake.v.02'),
#  Synset('share.v.04'),
#  Synset('share.v.05')]

# %%
wn.synset('contribution.n.01').lemma_names()
# Out:
# ['contribution', 'part', 'share']

# %%
wn.synset('stock_certificate.n.01').definition()
#'a motor vehicle with four wheels; usually propelled by an internal combustion engine'
wn.synset('stock_certificate.n.01').examples()
# Out:
# ['the value of his stocks doubled during the past year']

# %%
a = wn.synsets('stock')

# %%
wn.synset('stock.n.02').lemma_names()
# Out:
# ['stock', 'inventory']

# %%
wn.synset('stock_certificate.n.01').lemma_names()
# Out:
# ['stock_certificate', 'stock']

# %%
from nltk.corpus import wordnet as wn
for ss in wn.synsets('stock'):
   print(ss, ss.definition())
# Out:
# Synset('stock.n.01') the capital raised by a corporation through the issue of shares entitling holders to an ownership interest (equity)
# Synset('stock.n.02') the merchandise that a shop has on hand
# Synset('stock.n.03') the handle of a handgun or the butt end of a rifle or shotgun or part of the support of a machine gun or artillery gun
# Synset('stock_certificate.n.01') a certificate documenting the shareholder's ownership in the corporation
# Synset('store.n.02') a supply of something available for future use
# Synset('lineage.n.01') the descendants of one individual
# Synset('breed.n.01') a special variety of domesticated animals within a species
# Synset('broth.n.01') liquid in which meat and vegetables are simmered; used as a basis for e.g. soups or sauces
# Synset('stock.n.09') the reputation and popularity a person has
# Synset('stock.n.10') persistent thickened stem of a herbaceous perennial plant
# Synset('stock.n.11') a plant or stem onto which a graft is made; especially a plant grown specifically to provide the root part of grafted plants
# Synset('stock.n.12') any of several Old World plants cultivated for their brightly colored flowers
# Synset('malcolm_stock.n.01') any of various ornamental flowering plants of the genus Malcolmia
# Synset('stock.n.14') lumber used in the construction of something
# Synset('stock.n.15') the handle end of some implements or tools
# Synset('neckcloth.n.01') an ornamental white cravat
# Synset('livestock.n.01') any animals kept for use or profit
# Synset('stock.v.01') have on hand
# Synset('stock.v.02') equip with a stock
# Synset('stock.v.03') supply with fish
# Synset('stock.v.04') supply with livestock
# Synset('stock.v.05') amass so as to keep for future use or sale or for a particular occasion or use
# Synset('stock.v.06') provide or furnish with a stock of something
# Synset('sprout.v.02') put forth and grow sprouts or shoots
# Synset('banal.s.01') repeated too often; overfamiliar through overuse
# Synset('stock.s.02') routine
# Synset('standard.s.05') regularly and widely used or sold

# %%
print(lesk(sent, 'bank', 'n'))
#Synset('savings_bank.n.02')
# Out:
# Synset('savings_bank.n.02')

# %%
from nltk.wsd import lesk
sent = ['I', 'went', 'to', 'the', 'bank', 'to', 'deposit', 'money', '.']

# %%
from nltk.wsd import lesk
sent = ['I', 'went', 'to', 'the', 'bank', 'to', 'deposit', 'money', '.']

# %%
sent = [
    "Tomato rates soar as Centre looks to south for new stock",]
    #"Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate"
#]

# %%
print(lesk(sent, 'stock', 'n'))
# Out:
# Synset('store.n.02')

# %%
wn.synset('store.n.02').definition()
# Out:
# 'a supply of something available for future use'

# %%
sent = [
    "Tomato rates soar as Centre looks to south for new stock",]
    "Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate"]
#]

# %%
lesk('John loves Mary'.split(), 'loves', synsets=[])

# %%
import nltk
from nltk.tokenize import word_tokenize

# List of sentences
sentences = [
    "Tomato rates soar as Centre looks to south for new stock",
    "Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate"
]

# Perform POS tagging
for sentence in sentences:
    # Tokenize the sentence
    tokens = word_tokenize(sentence)
    # Perform POS tagging
    pos_tags = nltk.pos_tag(tokens)
    # Print the results
    print(f"Sentence: {sentence}")
    print("POS Tags:", pos_tags)
    print()
# Out:
# Sentence: Tomato rates soar as Centre looks to south for new stock
# POS Tags: [('Tomato', 'NNP'), ('rates', 'NNS'), ('soar', 'VBP'), ('as', 'IN'), ('Centre', 'NNP'), ('looks', 'VBZ'), ('to', 'TO'), ('south', 'VB'), ('for', 'IN'), ('new', 'JJ'), ('stock', 'NN')]
#
# Sentence: Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate
# POS Tags: [('Indian', 'JJ'), ('stock', 'NN'), ('market', 'NN'), (':', ':'), ('6', 'CD'), ('key', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('changed', 'VBD'), ('for', 'IN'), ('market', 'NN'), ('overnight', 'JJ'), ('-', ':'), ('Gift', 'NN'), ('Nifty', 'NNP'), (',', ','), ('US', 'NNP'), ('Treasury', 'NNP'), ('yields', 'NNS'), ('to', 'TO'), ('gold', 'VB'), ('rate', 'NN')]

# %%
print(lesk(sent, 'stock', 'n'))
# Out:
# Synset('store.n.02')

# %%
wn.synset('store.n.02').definition()
# Out:
# 'a supply of something available for future use'

# %%
import nltk
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()
fourgram_measures = nltk.collocations.QuadgramAssocMeasures()
finder = BigramCollocationFinder.from_words(
 nltk.corpus.genesis.words('english-web.txt'))
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('Allon', 'Bacuth'),
#  ('Ashteroth', 'Karnaim'),
#  ('Ben', 'Ammi'),
#  ('En', 'Mishpat'),
#  ('Jegar', 'Sahadutha'),
#  ('Salt', 'Sea'),
#  ('Whoever', 'sheds'),
#  ('appoint', 'overseers'),
#  ('aromatic', 'resin'),
#  ('cutting', 'instrument')]

# %%
#text = "I do not like green eggs and ham, I do not like them Sam I am!"
for i in df.headline[:5]:
    tokens = nltk.wordpunct_tokenize(i)
    finder = BigramCollocationFinder.from_words(tokens)
    scored = finder.score_ngrams(bigram_measures.raw_freq)
    print(sorted(bigram for bigram, score in scored))
# Out:
# [("'", 'Will'), ("':", 'Kotak'), ('Bank', 'probing'), ('Capital', 'hid'), ('Hindenburg', 'Research'), ('Kingdon', 'Capital'), ('Kotak', 'Bank'), ('Research', 'links'), ('Will', 'explore'), ('explore', 'legal'), ('hid', 'Hindenburg'), ('if', 'Kingdon'), ('legal', 'options'), ('options', "':"), ('probing', 'if')]
# [('%', 'Gain'), ('3', '%'), ('As', 'Market'), ('Ends', 'Flat'), ('Flat', 'On'), ('Gain', 'As'), ('Gainers', 'With'), ('Leads', 'Nifty'), ('Market', 'Ends'), ('Nifty', 'Gainers'), ('ONGC', 'Leads'), ('On', 'Monday'), ('With', '3')]
# [('&', 'equity'), ('FDs', 'with'), ('SBI', 'wants'), ('bank', 'FDs'), ('equity', 'markets'), ('funds', '&'), ('in', 'Budget'), ('markets', 'in'), ('mutual', 'funds'), ('on', 'bank'), ('parity', 'on'), ('tax', 'parity'), ('wants', 'tax'), ('with', 'mutual')]
# [(',', '000'), ('-', 'Week'), ('000', 'Crore'), ('1', 'Year'), ('370', 'per'), ('52', '-'), ('85', ','), (':', 'Railway'), (';', 'Stock'), ('Book', ':'), ('Company', 'Hits'), ('Crore', 'Order'), ('Fresh', '52'), ('Gains', '370'), ('Heavy', 'Volumes'), ('High', 'with'), ('Hits', 'Fresh'), ('Infra', 'Company'), ('Just', '1'), ('Order', 'Book'), ('Railway', 'Infra'), ('Rs', '85'), ('Stock', 'Gains'), ('Volumes', ';'), ('Week', 'High'), ('cent', 'in'), ('in', 'Just'), ('per', 'cent'), ('with', 'Heavy')]
# [('9', ':'), (':', 'Investors'), ('As', 'Nifty'), ('Await', 'Q1'), ('Earnings', 'As'), ('Faces', 'Key'), ('For', 'July'), ('Investors', 'Await'), ('July', '9'), ('Key', 'Resistance'), ('Nifty', 'Faces'), ('Q1', 'Earnings'), ('Resistance', 'Levels'), ('Setup', 'For'), ('Trade', 'Setup')]

# %%
nltk.corpus.r
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 from nltk.corpus import news
#
# ImportError: cannot import name 'news' from 'nltk.corpus' (C:\Users\modza\Documents\nlp\env\Lib\site-packages\nltk\corpus\__init__.py)

# %%
from nltk.corpus import brown, movie_reviews, reuters
print(brown.categories())
print(movie_reviews.categories())

print(reuters.categories())
# Out:
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# ['neg', 'pos']
# ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee', 'copper', 'copra-cake', 'corn', 'cotton', 'cotton-oil', 'cpi', 'cpu', 'crude', 'dfl', 'dlr', 'dmk', 'earn', 'fuel', 'gas', 'gnp', 'gold', 'grain', 'groundnut', 'groundnut-oil', 'heat', 'hog', 'housing', 'income', 'instal-debt', 'interest', 'ipi', 'iron-steel', 'jet', 'jobs', 'l-cattle', 'lead', 'lei', 'lin-oil', 'livestock', 'lumber', 'meal-feed', 'money-fx', 'money-supply', 'naphtha', 'nat-gas', 'nickel', 'nkr', 'nzdlr', 'oat', 'oilseed', 'orange', 'palladium', 'palm-oil', 'palmkernel', 'pet-chem', 'platinum', 'potato', 'propane', 'rand', 'rape-oil', 'rapeseed', 'reserves', 'retail', 'rice', 'rubber', 'rye', 'ship', 'silver', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'strategic-metal', 'sugar', 'sun-meal', 'sun-oil', 'sunseed', 'tea', 'tin', 'trade', 'veg-oil', 'wheat', 'wpi', 'yen', 'zinc']

# %%
import textblob

# %%
t = textblob.sentiments.PatternAnalyzer()

# %%
t.analyze("Indian stock market: 6 key things that changed for market overnight - Gift Nifty, US Treasury yields to gold rate")
# Out:
# Sentiment(polarity=0.0, subjectivity=1.0)

# %%
from nltk.corpus import brown

# %%
brown.sents(

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
import nltk
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()
fourgram_measures = nltk.collocations.QuadgramAssocMeasures()
finder = BigramCollocationFinder.from_words(
 nltk.corpus.genesis.words('english-web.txt'))
finder.nbest(bigram_measures.pmi, 10)

# %%
[('Allon', 'Bacuth'), ('Ashteroth', 'Karnaim'), ('Ben', 'Ammi'),
('En', 'Mishpat'), ('Jegar', 'Sahadutha'), ('Salt', 'Sea'),
('Whoever', 'sheds'), ('appoint', 'overseers'), ('aromatic', 'resin'),
('cutting', 'instrument')]

# %%
# !git clone https://github.com/zafar0171/my_Realm
# Out:
# Cloning into 'my_Realm'...

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A9F-EF4E
#
#  Directory of C:\Users\modza\Documents\nlp
#
# 21-07-2024  00:30    <DIR>          .
# 21-07-2024  00:30    <DIR>          ..
# 19-07-2024  19:35    <DIR>          .ipynb_checkpoints
# 18-01-2024  18:15           206,295 1. Text Classification - SMS.ipynb
# 30-01-2024  01:14            82,191 adobe.jpg
# 15-07-2024  16:07               123 corenlp_server-099517907f7a49a2.props
# 15-07-2024  13:35               123 corenlp_server-49648ec25afe4f13.props
# 15-07-2024  13:35               179 corenlp_server-d0c3292baa644e50.props
# 28-01-2024  02:07             2,063 dataset_infos.json
# 19-07-2024  19:34           115,932 Data_for_semantic_analysis.csv
# 18-01-2024  18:15           179,869 DocumentSimilarityClustering_v1.ipynb
# 17-01-2024  16:36    <DIR>          env
# 29-01-2024  01:32            12,489 extracted_text.csv
# 23-01-2024  12:39            62,533 Face_recog.ipynb
# 23-01-2024  12:47    <DIR>          flagged
# 17-07-2024  15:01           503,912 google_news.csv
# 18-07-2024  23:27                 0 highlighted_entities.html
# 09-04-2024  22:35           176,140 Image_Classification.ipynb
# 07-04-2024  22:16            37,485 istockphoto-1310856881-612x612.jpg
# 27-01-2024  23:26       942,326,956 London_reviews.csv
# 09-02-2024  22:05            35,332 mcc_al.xml
# 09-04-2024  22:24            15,449 MNIST.ipynb
# 09-02-2024  19:35           398,246 Modified_DataScraping_NER_SentimentAnalysis.ipynb
# 19-07-2024  20:59         4,568,613 Module-1---NER.ipynb
# 01-02-2024  22:34            46,975 MongoDB_sampleData.ipynb
# 21-07-2024  00:30    <DIR>          my_Realm
# 17-07-2024  18:55           241,925 named entity recognition.ipynb
# 31-01-2024  00:10            34,141 news.csv
# 18-07-2024  15:28            26,479 newsandorg,csv
# 19-07-2024  15:29            26,479 newsandorg.csv
# 18-07-2024  01:10         6,810,315 News_scraping.ipynb
# 07-04-2024  21:42           290,351 photo-1601584115197-04ecc0da31d7.avif
# 28-04-2024  11:12         4,946,247 Plotly_debugging.ipynb
# 02-02-2024  00:25            95,551 Practice.ipynb
# 30-01-2024  12:45        25,180,198 Practice_stemandlem.ipynb
# 13-04-2024  18:00            24,591 Quote-Equity-SUNDARAM-EQ-12-04-2020-to-12-04-2021.csv
# 13-04-2024  18:00             9,286 Quote-Equity-SUNDARAM-EQ-12-04-2021-to-12-04-2022.csv
# 13-04-2024  18:00            28,408 Quote-Equity-SUNDARAM-EQ-12-04-2022-to-12-04-2023.csv
# 12-04-2024  21:34            18,021 Quote-Equity-SUNDARAM-EQ-12-04-2023-to-12-04-2024.csv
# 01-02-2024  21:39           265,670 screen_after_search.png
# 23-01-2024  15:29           477,907 sms.tsv
# 25-01-2024  13:15            21,062 stable_video_diffusion_img2vid.ipynb
# 18-01-2024  19:01            39,833 Stemming _ Lemmatization using NLTK.ipynb
# 25-01-2024  16:32            51,941 stemmingLemmatization.ipynb
# 15-04-2024  12:23           170,847 Sundaram multi.ipynb
# 08-04-2024  22:36           239,042 tensorflow_CIFAR10.ipynb
# 23-01-2024  21:39                31 test.csv
# 18-01-2024  19:18           206,360 textAnalytics.ipynb
# 28-01-2024  00:29         5,289,312 twitter-sentiment-analysis-lstm.ipynb
# 09-02-2024  22:07        17,442,710 TwitterData.ipynb
# 27-01-2024  23:10        20,895,533 Twitter_Data.csv
# 28-01-2024  12:36           105,303 Untitled.ipynb
# 24-01-2024  23:49           133,148 Untitled1.ipynb
# 28-01-2024  18:36             1,452 Untitled2.ipynb
# 30-01-2024  23:55           319,532 Untitled3.ipynb
# 10-02-2024  13:26           632,902 Untitled4.ipynb
# 12-04-2024  13:47            59,438 Untitled5.ipynb
# 21-07-2024  00:30           459,914 Untitled6.ipynb
# 26-01-2024  22:18           128,905 url.txt
# 18-01-2024  18:15            17,250 Using spaCy.ipynb
# 01-02-2024  20:44            13,532 WhatsApp Image 2024-02-01 at 20.44.11_4c8d3c60.jpg
# 28-01-2024  20:09         6,077,253 Whiteboard 28 Jan 2024.pdf
# 18-01-2024  19:11         8,091,185 yelp.csv
#               57 File(s)  1,047,642,959 bytes
#                6 Dir(s)  23,830,618,112 bytes free
