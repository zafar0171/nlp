# %%
# !pip install pytorch
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for pytorch
# Failed to build pytorch
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\modza\AppData\Local\Temp\pip-install-2sf6aqnr\pytorch_0b34672c63ce483ab81286c2eb592160\setup.py", line 15, in <module>
#       raise Exception(message)
#   Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
# ERROR: Could not build wheels for pytorch, which is required to install pyproject.toml-based projects
# ...

# %%
from torch.utils.data import DataLoader

# %%
import os

# %%
ad = pd.Series([1,23,4,56,7])

# %%
ad.to_csv('test.csv')

# %%
import pandas as pd

# %%
import gradio as gr

# %%
gr.interface(

# %%
import numpy as np

# %%
np.linalg.linalg.

# %%
AttributeError: module 'numpy.linalg._umath_linalg' has no attribute '_ilp64'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\modza\\Documents\\nlp'

# %%
os.getcwdb()
# Out:
# b'C:\\Users\\modza\\Documents\\nlp'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1. Text Classification - SMS.ipynb',
#  'DataScraping_NER_SentimentAnalysis.ipynb',
#  'DocumentSimilarityClustering_v1.ipynb',
#  'env',
#  'Stemming _ Lemmatization using NLTK.ipynb',
#  'stemmingLemmatization.ipynb',
#  'textAnalytics.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Using spaCy.ipynb',
#  'yelp.csv']

# %%
os.chdir('C:\\users\\modza\\documents')

# %%
os.getcwd()
# Out:
# 'C:\\users\\modza\\documents'

# %%
os.chdir('C:\\users\\modza\\documents\\nlp')

# %%
os.path.getctime('C:\\users\\modza\\download (1).jpeg',flags = os.O_RDONLY)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 os.path.getctime('C:\\users\\modza\\download (1).jpeg')
#
# File <frozen genericpath>:65, in getctime(filename)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\users\\modza\\download (1).jpeg'

# %%
ad = os.open('C:\\users\\modza\\downloads\\image.jpg', os.O_RDONLY)

# %%
Image.blend()
# Out:
# 5

# %%
from PIL import Image

# %%
ad = Image.open('C:\\users\\modza\\downloads\\image.jpg')
ad1 = Image.open('C:\\users\\modza\\downloads\\wp5282645.jpg')

# %%
Image.blend(ad,ad1,0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 Image.blend(ad,ad1,0.3)
#
# File ~\Documents\nlp\env\Lib\site-packages\PIL\Image.py:3322, in blend(im1, im2, alpha)
#    3320 im1.load()
#    3321 im2.load()
# -> 3322 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# ValueError: images do not match

# %%
Image.radial_gradient()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 Image.radial_gradient()
#
# TypeError: radial_gradient() missing 1 required positional argument: 'mode'

# %%
import gradio as gr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 import gradio as gr
#
# File ~\Documents\nlp\env\Lib\site-packages\gradio\__init__.py:3
#       1 import json
# ----> 3 import gradio._simple_templates
#       4 import gradio.components as components
#       5 import gradio.image_utils
#
# File ~\Documents\nlp\env\Lib\site-packages\gradio\_simple_templates\__init__.py:1
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpletextbox import SimpleTextbox
#       4 __all__ = ["SimpleDropdown", "SimpleTextbox"]
#
# File ~\Documents\nlp\env\Lib\site-packages\gradio\_simple_templates\simpledropdown.py:6
#       3 import warnings
#       4 from typing import Any, Callable
# ----> 6 from gradio.components.base import FormComponent
#       7 from gradio.events import Events
#      10 class SimpleDropdown(FormComponent):
#
# ...

# %%
import cv2

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# ...

# %%
# !pip install --upgrade typing-extensions

# %%
# !pip install gradio
# Out:
# ...
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached fastapi-0.109.0-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached ffmpy-0.3.1-py3-none-any.whl
# ...
#   Using cached httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# ...
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 50.6/50.6 kB 517.4 kB/s eta 0:00:00
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# ...
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached websockets-11.0.3-cp311-cp311-win_amd64.whl (124 kB)
# ...

# %%
import gradio as gr

# %%
gr.Audio(streaming = True)
# Out:
# audio

# %%
import gradio as gr

def process_audio(audio):
    # Your audio processing logic goes here
    return audio

interface = gr.Interface(
    fn=process_audio, 
    inputs=gr.Audio(sources = ['microphone'],streaming=True), 
    outputs="audio"
)

interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
interface = gr.Interface(
    inputs=gr.Audio(sources="microphone", type="filepath", streaming=False),
    outputs="audio"
)

interface.launch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 interface = gr.Interface(
#       2     inputs=gr.Audio(sources="microphone", type="filepath", streaming=False),
#       3     outputs="audio"
#       4 )
#       6 interface.launch()
#
# TypeError: Interface.__init__() missing 1 required positional argument: 'fn'

# %%
print(dir(os))
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 
# ...
